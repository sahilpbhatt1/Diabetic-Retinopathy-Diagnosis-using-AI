# %%
# Import the necessary packages

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import os
import matplotlib.pyplot as plt
import PIL
import seaborn as sns
import plotly
import plotly.graph_objs as go
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from plotly.offline import iplot, init_notebook_mode
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from IPython.display import display
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler

from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False) 
# setting the style of the notebook to be monokai theme  
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
os.listdir('./train')
# Out:
# ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']

# %%
os.listdir(os.path.join('train','Mild'))
# Out:
# ['0024cdab0c1e.png',
#  '00cb6555d108.png',
#  '0124dffecf29.png',
#  '01b3aed3ed4c.png',
#  '0369f3efe69b.png',
#  '03e25101e8e8.png',
#  '04ac765f91a1.png',
#  '059bc89df7f4.png',
#  '05a5183c92d0.png',
#  '0684311afdfc.png',
#  '06b71823f9cd.png',
#  '07929d32b5b3.png',
#  '07a1c7073982.png',
#  '086d41d17da8.png',
#  '09935d72892b.png',
#  '0a3202889f4d.png',
#  '0a61bddab956.png',
#  '0ad7f631dedb.png',
#  '0d310aba6373.png',
#  '0dc031c94225.png',
#  '0dce95217626.png',
#  '0eb52045349f.png',
#  '0f495d87656a.png',
#  '0fb1053285cf.png',
#  '101b9ebfc720.png',
#  '107aea0d9289.png',
#  '10f36b0239fb.png',
#  '1116271db4ea.png',
#  '111898ab463d.png',
#  '12ce6a1a1f31.png',
#  '12e3f5f2cb17.png',
#  '13ab8db8c700.png',
#  '15cc2aef772a.png',
#  '172df1330a60.png',
#  '17eff993386f.png',
#  '18b06f56ab27.png',
#  '194814669fee.png',
#  '19722bff5a09.png',
#  '19e350c7c83c.png',
#  '1a03a7970337.png',
#  '1b329a127307.png',
#  '1bb0ddfe753a.png',
#  '1c0cf251b426.png',
#  '1c3a6b4449e9.png',
#  '1d11794057ff.png',
#  '1d674e2e32e0.png',
#  '1df3e03a8f5f.png',
#  '1e8a1fdee5b9.png',
#  '200d947f75db.png',
#  '22098b1fe461.png',
#  '22325552a4e3.png',
#  '22a6da005395.png',
#  '248139c423c4.png',
#  '24b943fe725e.png',
#  '259d30f693b6.png',
#  '25e9fd872182.png',
#  '274f5029189b.png',
#  '278aa860dffd.png',
#  '27e4c800a449.png',
#  '28f98cfe3858.png',
#  '2994f17f58a5.png',
#  '29b52f64d2db.png',
#  '2a08ed6bbcbc.png',
#  '2a8a9e957a6c.png',
#  '2d7666b8884f.png',
#  '2d9d97a6e713.png',
#  '2ecbc2e3f239.png',
#  '2f2e1949ad56.png',
#  '2f4e81787d9b.png',
#  '3044022c6969.png',
#  '30941b65348b.png',
#  '30cab14951ac.png',
#  '31cb39681f6a.png',
#  '33105f9b3a04.png',
#  '33b893e18eb3.png',
#  '33ffddea8c6e.png',
#  '3461dc601cc2.png',
#  '358d2224de73.png',
#  '35aa7f5c2ec0.png',
#  '35d6c4c50072.png',
#  '36041171f441.png',
#  '365f8c01d994.png',
#  '36677b70b1ef.png',
#  '382752f6694a.png',
#  '384631079d1e.png',
#  '38b9bb961847.png',
#  '38e0e28d35d3.png',
#  '3b73a3a4a734.png',
#  '3c726de3ee90.png',
#  '3c72f580d4ba.png',
#  '3dbc90c7ee7d.png',
#  '3de8ad4151e1.png',
#  '3ee17aa12e46.png',
#  '3f73c91b7e32.png',
#  '4029d70e9d8a.png',
#  '40e9b5630438.png',
#  '4393c5bc576a.png',
#  '45e4b7eada54.png',
#  '4661006f3ba6.png',
#  '47d1603a555b.png',
#  '49386d603494.png',
#  '494fc9c745a3.png',
#  '495255c7492f.png',
#  '49c5e7f6b8d2.png',
#  '4a213b405ee4.png',
#  '4aa07d720638.png',
#  '4c129470cec4.png',
#  '4c3c1ed09771.png',
#  '4cae247d9909.png',
#  '4d7d6928534a.png',
#  '4da2961e62fe.png',
#  '4dd5d5ccddcf.png',
#  '4dd9d29eae5d.png',
#  '4e0656629d02.png',
#  '4e6071b73120.png',
#  '4e82c3c8d31f.png',
#  '4ecd1fdd1435.png',
#  '4ef7144e24ff.png',
#  '4f7755e74a9e.png',
#  '4fa26d065ad3.png',
#  '50840c36f0b4.png',
#  '5090917a2676.png',
#  '51131b48f9d4.png',
#  '513b0a4651fa.png',
#  '523b3f0fc646.png',
#  '52ae917fcea4.png',
#  '531b39880c32.png',
#  '5347b4c8e9b3.png',
#  '53704c80f0d8.png',
#  '53f6c1c65c04.png',
#  '545df1bbcd61.png',
#  '5548a7961a3e.png',
#  '55eac26bd383.png',
#  '5633ced07d8e.png',
#  '5671eb95512b.png',
#  '5712e2aa73a2.png',
#  '5777ef74c9ec.png',
#  '578109578b46.png',
#  '58184d6fd087.png',
#  '582115961a3d.png',
#  '587146a55885.png',
#  '5879285f9d8d.png',
#  '58ccba7eec9c.png',
#  '595446774178.png',
#  '59e5212f7139.png',
#  '5a091e8cd95c.png',
#  '5b068765e846.png',
#  '5b0e53f53ef3.png',
#  '5b72ff04333d.png',
#  '5b804948e35f.png',
#  '5cab3ef4b31c.png',
#  '5efa24b03d5e.png',
#  '6028a575dc27.png',
#  '613bacb35c05.png',
#  '6165081b9021.png',
#  '61bbe8db6f3a.png',
#  '6298468d7d75.png',
#  '63363410389a.png',
#  '6377e23928f6.png',
#  '63a03880939c.png',
#  '64678182d8a8.png',
#  '64eb5a79dfdd.png',
#  '655cafb4c932.png',
#  '65e51e18242b.png',
#  '665ce639a331.png',
#  '66cd9c28e636.png',
#  '6762b2b48ea5.png',
#  '677f087cd697.png',
#  '67f5d89da548.png',
#  '68332fdcaa70.png',
#  '6b00cb764237.png',
#  '6b07971c3bf6.png',
#  '6c6efb6b1358.png',
#  '6cdd0f985270.png',
#  '6d292ca4c9ad.png',
#  '6ea07d19b4ce.png',
#  '7005be54cab1.png',
#  '7116128c65ab.png',
#  '71c1a3cdbe47.png',
#  '71f6a6e4620a.png',
#  '7335a2d43ada.png',
#  '7347f5133a6a.png',
#  '73881f55a3ec.png',
#  '7427dedafccf.png',
#  '756b0d6488bb.png',
#  '76be29bb30b2.png',
#  '76e589911303.png',
#  '77a9538b8362.png',
#  '78bcdffb8785.png',
#  '79ce83c07588.png',
#  '7a3ea1779b13.png',
#  '7ae69d22075a.png',
#  '7b20210d9120.png',
#  '7bf981d9c7fe.png',
#  '7ccb267fd394.png',
#  '7ea756985353.png',
#  '7ef5ff774a48.png',
#  '7f60f2a083d3.png',
#  '80a02014b418.png',
#  '80d24897669f.png',
#  '8114d6a160df.png',
#  '821789e9053f.png',
#  '8273fdb4405e.png',
#  '82ac8463fadd.png',
#  '83e529e95b0e.png',
#  '849a91e9ab28.png',
#  '84a72e15b23c.png',
#  '8676427e4625.png',
#  '8714d17bb6da.png',
#  '89d9c071a56f.png',
#  '89ed6a0dd53f.png',
#  '8a01daa423f7.png',
#  '8a25a080f28f.png',
#  '8bbd7835e9aa.png',
#  '8bc6716c2238.png',
#  '8c2f0f04e1ed.png',
#  '8dc22e65c06f.png',
#  '8ef2eb8c51c4.png',
#  '8f2996b8d855.png',
#  '8fc09fecd22f.png',
#  '8ff863f8874f.png',
#  '90c982cc2d96.png',
#  '92d9e9f08709.png',
#  '93be637084a2.png',
#  '94111ed3d276.png',
#  '94372043d55b.png',
#  '944a233fbf8e.png',
#  '94b1d8ad35ec.png',
#  '95a4cc805c7b.png',
#  '96a9706b8534.png',
#  '977e1ca77653.png',
#  '9782c0489eca.png',
#  '98fbe56dcc2c.png',
#  '99132193eaa0.png',
#  '99ecdb41d5e7.png',
#  '9a3109657ac1.png',
#  '9eaf735cf01f.png',
#  '9ed666e982cd.png',
#  'a00b4cb250a7.png',
#  'a01024054596.png',
#  'a19ecd0a706e.png',
#  'a2696f444ecb.png',
#  'a28bfb772f50.png',
#  'a32886cb31ab.png',
#  'a3ad6c2db6f1.png',
#  'a3d2a0c4cd17.png',
#  'a443c4fd489c.png',
#  'a47432cd41e7.png',
#  'a5a2a7003d60.png',
#  'a75bab2463d4.png',
#  'a77dbec966d4.png',
#  'a7ec056502e7.png',
#  'a8582e346df0.png',
#  'a8c54e2a4b79.png',
#  'a8c950a99107.png',
#  'a95858e052d6.png',
#  'ababe19ed448.png',
#  'abdb365cacbc.png',
#  'ad1f7445b1a8.png',
#  'ad3fc5076852.png',
#  'ae8472f8d310.png',
#  'af133a85ea0c.png',
#  'b07bc463b718.png',
#  'b1197f2cc9b3.png',
#  'b17f0b81dab3.png',
#  'b22354b5f94b.png',
#  'b4f41b5bf0ef.png',
#  'b50b30aa6e6c.png',
#  'b56340f472d2.png',
#  'b576c5269ad1.png',
#  'b640e3bdff75.png',
#  'b6a0e348a01e.png',
#  'b71428739d4e.png',
#  'b7278b4f2448.png',
#  'b8ebedd382de.png',
#  'b94c58d063bf.png',
#  'b9b99dad668d.png',
#  'bacfb1029f6b.png',
#  'bb11db08584a.png',
#  'bb45257258cc.png',
#  'bb783d8e496f.png',
#  'bb9a3d835a94.png',
#  'bc73ce76ec43.png',
#  'bd269a1f0e4d.png',
#  'bebb3f167654.png',
#  'bf18ff30a8f6.png',
#  'c027e5482e8c.png',
#  'c0968d41eb93.png',
#  'c0e15e8e2b46.png',
#  'c0f15fe3b4b7.png',
#  'c102db7634d8.png',
#  'c1e6fa1ad314.png',
#  'c1ebe785503a.png',
#  'c40976189f22.png',
#  'c4a8f2fcf6e8.png',
#  'c56e65f74187.png',
#  'c739ff9580d3.png',
#  'c7b622ec8104.png',
#  'c8fc0df22999.png',
#  'c9485c38fdd5.png',
#  'c96f743915b5.png',
#  'ca1036496659.png',
#  'ca25745942b0.png',
#  'ca30a97e9d13.png',
#  'ca63fe4f4b52.png',
#  'ca6842bfcbc9.png',
#  'ca7140ecf389.png',
#  'cab3dfa7962d.png',
#  'cae51154e1ce.png',
#  'cb2f3c5d71a7.png',
#  'cc12453ea915.png',
#  'cc9270f06b65.png',
#  'cd45bfa07d41.png',
#  'cd5714db652d.png',
#  'cf0575534cec.png',
#  'cf603a9ef2d5.png',
#  'cfd1bd0fcbb4.png',
#  'd06ccd0cf4b8.png',
#  'd0d59ed675b5.png',
#  'd1cad012a254.png',
#  'd3de0d313d61.png',
#  'd4f32b9c07df.png',
#  'd567a1a22d33.png',
#  'd5b4705ac2ee.png',
#  'd66b6f333dc7.png',
#  'd66ccb75ada1.png',
#  'd6e26fe51dce.png',
#  'd801c0a66738.png',
#  'd85588ff2ebd.png',
#  'd85d052900b4.png',
#  'da1fb35f5df9.png',
#  'db4ed1e07aa3.png',
#  'db690e2d02f8.png',
#  'dbd062558b81.png',
#  'dd19428c3d29.png',
#  'e07045d7c5f7.png',
#  'e25ccfe38e44.png',
#  'e26d8718ca58.png',
#  'e2a233493b90.png',
#  'e38f3a65b02b.png',
#  'e55188915f9d.png',
#  'e580676516b0.png',
#  'e9286ddf6ffe.png',
#  'e96bd80a8a53.png',
#  'e9ff9352ccb3.png',
#  'ea15a290eb96.png',
#  'ead23cc922ed.png',
#  'eba3acc42197.png',
#  'ec4649213ccf.png',
#  'ee78ce914066.png',
#  'eeb231c3ef1f.png',
#  'eed4afc8ec83.png',
#  'ef8109305128.png',
#  'f0c13be90519.png',
#  'f47a2a4a0411.png',
#  'f481f76a6b75.png',
#  'f55e1d2a19e4.png',
#  'f5650eb52640.png',
#  'f6f7dba7104d.png',
#  'f72ef9ceeaa8.png',
#  'f762c272c522.png',
#  'f7fec8935126.png',
#  'fb6b8200b7f8.png',
#  'fca931da5c5e.png',
#  'fd62bd0db4f1.png',
#  'fdd18ccbbdc5.png',
#  'fe2df69676cf.png',
#  'fe674c2f73f5.png',
#  'fea14b3d44b0.png',
#  'fecf4c5ae84b.png']

# %%
train = []
label = []

for i in os.listdir('./train'): 
    train_class = os.listdir(os.path.join('train', i))
    for j in train_class:
        img = os.path.join('train', i, j)
        train.append(img)
        label.append(i)
        
print('Number of train images: ', len(train))
# Out:
# Number of train images:  3662

# %%
train
# Out:
# ['train\\Mild\\0024cdab0c1e.png',
#  'train\\Mild\\00cb6555d108.png',
#  'train\\Mild\\0124dffecf29.png',
#  'train\\Mild\\01b3aed3ed4c.png',
#  'train\\Mild\\0369f3efe69b.png',
#  'train\\Mild\\03e25101e8e8.png',
#  'train\\Mild\\04ac765f91a1.png',
#  'train\\Mild\\059bc89df7f4.png',
#  'train\\Mild\\05a5183c92d0.png',
#  'train\\Mild\\0684311afdfc.png',
#  'train\\Mild\\06b71823f9cd.png',
#  'train\\Mild\\07929d32b5b3.png',
#  'train\\Mild\\07a1c7073982.png',
#  'train\\Mild\\086d41d17da8.png',
#  'train\\Mild\\09935d72892b.png',
#  'train\\Mild\\0a3202889f4d.png',
#  'train\\Mild\\0a61bddab956.png',
#  'train\\Mild\\0ad7f631dedb.png',
#  'train\\Mild\\0d310aba6373.png',
#  'train\\Mild\\0dc031c94225.png',
#  'train\\Mild\\0dce95217626.png',
#  'train\\Mild\\0eb52045349f.png',
#  'train\\Mild\\0f495d87656a.png',
#  'train\\Mild\\0fb1053285cf.png',
#  'train\\Mild\\101b9ebfc720.png',
#  'train\\Mild\\107aea0d9289.png',
#  'train\\Mild\\10f36b0239fb.png',
#  'train\\Mild\\1116271db4ea.png',
#  'train\\Mild\\111898ab463d.png',
#  'train\\Mild\\12ce6a1a1f31.png',
#  'train\\Mild\\12e3f5f2cb17.png',
#  'train\\Mild\\13ab8db8c700.png',
#  'train\\Mild\\15cc2aef772a.png',
#  'train\\Mild\\172df1330a60.png',
#  'train\\Mild\\17eff993386f.png',
#  'train\\Mild\\18b06f56ab27.png',
#  'train\\Mild\\194814669fee.png',
#  'train\\Mild\\19722bff5a09.png',
#  'train\\Mild\\19e350c7c83c.png',
#  'train\\Mild\\1a03a7970337.png',
#  'train\\Mild\\1b329a127307.png',
#  'train\\Mild\\1bb0ddfe753a.png',
#  'train\\Mild\\1c0cf251b426.png',
#  'train\\Mild\\1c3a6b4449e9.png',
#  'train\\Mild\\1d11794057ff.png',
#  'train\\Mild\\1d674e2e32e0.png',
#  'train\\Mild\\1df3e03a8f5f.png',
#  'train\\Mild\\1e8a1fdee5b9.png',
#  'train\\Mild\\200d947f75db.png',
#  'train\\Mild\\22098b1fe461.png',
#  'train\\Mild\\22325552a4e3.png',
#  'train\\Mild\\22a6da005395.png',
#  'train\\Mild\\248139c423c4.png',
#  'train\\Mild\\24b943fe725e.png',
#  'train\\Mild\\259d30f693b6.png',
#  'train\\Mild\\25e9fd872182.png',
#  'train\\Mild\\274f5029189b.png',
#  'train\\Mild\\278aa860dffd.png',
#  'train\\Mild\\27e4c800a449.png',
#  'train\\Mild\\28f98cfe3858.png',
#  'train\\Mild\\2994f17f58a5.png',
#  'train\\Mild\\29b52f64d2db.png',
#  'train\\Mild\\2a08ed6bbcbc.png',
#  'train\\Mild\\2a8a9e957a6c.png',
#  'train\\Mild\\2d7666b8884f.png',
#  'train\\Mild\\2d9d97a6e713.png',
#  'train\\Mild\\2ecbc2e3f239.png',
#  'train\\Mild\\2f2e1949ad56.png',
#  'train\\Mild\\2f4e81787d9b.png',
#  'train\\Mild\\3044022c6969.png',
#  'train\\Mild\\30941b65348b.png',
#  'train\\Mild\\30cab14951ac.png',
#  'train\\Mild\\31cb39681f6a.png',
#  'train\\Mild\\33105f9b3a04.png',
#  'train\\Mild\\33b893e18eb3.png',
#  'train\\Mild\\33ffddea8c6e.png',
#  'train\\Mild\\3461dc601cc2.png',
#  'train\\Mild\\358d2224de73.png',
#  'train\\Mild\\35aa7f5c2ec0.png',
#  'train\\Mild\\35d6c4c50072.png',
#  'train\\Mild\\36041171f441.png',
#  'train\\Mild\\365f8c01d994.png',
#  'train\\Mild\\36677b70b1ef.png',
#  'train\\Mild\\382752f6694a.png',
#  'train\\Mild\\384631079d1e.png',
#  'train\\Mild\\38b9bb961847.png',
#  'train\\Mild\\38e0e28d35d3.png',
#  'train\\Mild\\3b73a3a4a734.png',
#  'train\\Mild\\3c726de3ee90.png',
#  'train\\Mild\\3c72f580d4ba.png',
#  'train\\Mild\\3dbc90c7ee7d.png',
#  'train\\Mild\\3de8ad4151e1.png',
#  'train\\Mild\\3ee17aa12e46.png',
#  'train\\Mild\\3f73c91b7e32.png',
#  'train\\Mild\\4029d70e9d8a.png',
#  'train\\Mild\\40e9b5630438.png',
#  'train\\Mild\\4393c5bc576a.png',
#  'train\\Mild\\45e4b7eada54.png',
#  'train\\Mild\\4661006f3ba6.png',
#  'train\\Mild\\47d1603a555b.png',
#  'train\\Mild\\49386d603494.png',
#  'train\\Mild\\494fc9c745a3.png',
#  'train\\Mild\\495255c7492f.png',
#  'train\\Mild\\49c5e7f6b8d2.png',
#  'train\\Mild\\4a213b405ee4.png',
#  'train\\Mild\\4aa07d720638.png',
#  'train\\Mild\\4c129470cec4.png',
#  'train\\Mild\\4c3c1ed09771.png',
#  'train\\Mild\\4cae247d9909.png',
#  'train\\Mild\\4d7d6928534a.png',
#  'train\\Mild\\4da2961e62fe.png',
#  'train\\Mild\\4dd5d5ccddcf.png',
#  'train\\Mild\\4dd9d29eae5d.png',
#  'train\\Mild\\4e0656629d02.png',
#  'train\\Mild\\4e6071b73120.png',
#  'train\\Mild\\4e82c3c8d31f.png',
#  'train\\Mild\\4ecd1fdd1435.png',
#  'train\\Mild\\4ef7144e24ff.png',
#  'train\\Mild\\4f7755e74a9e.png',
#  'train\\Mild\\4fa26d065ad3.png',
#  'train\\Mild\\50840c36f0b4.png',
#  'train\\Mild\\5090917a2676.png',
#  'train\\Mild\\51131b48f9d4.png',
#  'train\\Mild\\513b0a4651fa.png',
#  'train\\Mild\\523b3f0fc646.png',
#  'train\\Mild\\52ae917fcea4.png',
#  'train\\Mild\\531b39880c32.png',
#  'train\\Mild\\5347b4c8e9b3.png',
#  'train\\Mild\\53704c80f0d8.png',
#  'train\\Mild\\53f6c1c65c04.png',
#  'train\\Mild\\545df1bbcd61.png',
#  'train\\Mild\\5548a7961a3e.png',
#  'train\\Mild\\55eac26bd383.png',
#  'train\\Mild\\5633ced07d8e.png',
#  'train\\Mild\\5671eb95512b.png',
#  'train\\Mild\\5712e2aa73a2.png',
#  'train\\Mild\\5777ef74c9ec.png',
#  'train\\Mild\\578109578b46.png',
#  'train\\Mild\\58184d6fd087.png',
#  'train\\Mild\\582115961a3d.png',
#  'train\\Mild\\587146a55885.png',
#  'train\\Mild\\5879285f9d8d.png',
#  'train\\Mild\\58ccba7eec9c.png',
#  'train\\Mild\\595446774178.png',
#  'train\\Mild\\59e5212f7139.png',
#  'train\\Mild\\5a091e8cd95c.png',
#  'train\\Mild\\5b068765e846.png',
#  'train\\Mild\\5b0e53f53ef3.png',
#  'train\\Mild\\5b72ff04333d.png',
#  'train\\Mild\\5b804948e35f.png',
#  'train\\Mild\\5cab3ef4b31c.png',
#  'train\\Mild\\5efa24b03d5e.png',
#  'train\\Mild\\6028a575dc27.png',
#  'train\\Mild\\613bacb35c05.png',
#  'train\\Mild\\6165081b9021.png',
#  'train\\Mild\\61bbe8db6f3a.png',
#  'train\\Mild\\6298468d7d75.png',
#  'train\\Mild\\63363410389a.png',
#  'train\\Mild\\6377e23928f6.png',
#  'train\\Mild\\63a03880939c.png',
#  'train\\Mild\\64678182d8a8.png',
#  'train\\Mild\\64eb5a79dfdd.png',
#  'train\\Mild\\655cafb4c932.png',
#  'train\\Mild\\65e51e18242b.png',
#  'train\\Mild\\665ce639a331.png',
#  'train\\Mild\\66cd9c28e636.png',
#  'train\\Mild\\6762b2b48ea5.png',
#  'train\\Mild\\677f087cd697.png',
#  'train\\Mild\\67f5d89da548.png',
#  'train\\Mild\\68332fdcaa70.png',
#  'train\\Mild\\6b00cb764237.png',
#  'train\\Mild\\6b07971c3bf6.png',
#  'train\\Mild\\6c6efb6b1358.png',
#  'train\\Mild\\6cdd0f985270.png',
#  'train\\Mild\\6d292ca4c9ad.png',
#  'train\\Mild\\6ea07d19b4ce.png',
#  'train\\Mild\\7005be54cab1.png',
#  'train\\Mild\\7116128c65ab.png',
#  'train\\Mild\\71c1a3cdbe47.png',
#  'train\\Mild\\71f6a6e4620a.png',
#  'train\\Mild\\7335a2d43ada.png',
#  'train\\Mild\\7347f5133a6a.png',
#  'train\\Mild\\73881f55a3ec.png',
#  'train\\Mild\\7427dedafccf.png',
#  'train\\Mild\\756b0d6488bb.png',
#  'train\\Mild\\76be29bb30b2.png',
#  'train\\Mild\\76e589911303.png',
#  'train\\Mild\\77a9538b8362.png',
#  'train\\Mild\\78bcdffb8785.png',
#  'train\\Mild\\79ce83c07588.png',
#  'train\\Mild\\7a3ea1779b13.png',
#  'train\\Mild\\7ae69d22075a.png',
#  'train\\Mild\\7b20210d9120.png',
#  'train\\Mild\\7bf981d9c7fe.png',
#  'train\\Mild\\7ccb267fd394.png',
#  'train\\Mild\\7ea756985353.png',
#  'train\\Mild\\7ef5ff774a48.png',
#  'train\\Mild\\7f60f2a083d3.png',
#  'train\\Mild\\80a02014b418.png',
#  'train\\Mild\\80d24897669f.png',
#  'train\\Mild\\8114d6a160df.png',
#  'train\\Mild\\821789e9053f.png',
#  'train\\Mild\\8273fdb4405e.png',
#  'train\\Mild\\82ac8463fadd.png',
#  'train\\Mild\\83e529e95b0e.png',
#  'train\\Mild\\849a91e9ab28.png',
#  'train\\Mild\\84a72e15b23c.png',
#  'train\\Mild\\8676427e4625.png',
#  'train\\Mild\\8714d17bb6da.png',
#  'train\\Mild\\89d9c071a56f.png',
#  'train\\Mild\\89ed6a0dd53f.png',
#  'train\\Mild\\8a01daa423f7.png',
#  'train\\Mild\\8a25a080f28f.png',
#  'train\\Mild\\8bbd7835e9aa.png',
#  'train\\Mild\\8bc6716c2238.png',
#  'train\\Mild\\8c2f0f04e1ed.png',
#  'train\\Mild\\8dc22e65c06f.png',
#  'train\\Mild\\8ef2eb8c51c4.png',
#  'train\\Mild\\8f2996b8d855.png',
#  'train\\Mild\\8fc09fecd22f.png',
#  'train\\Mild\\8ff863f8874f.png',
#  'train\\Mild\\90c982cc2d96.png',
#  'train\\Mild\\92d9e9f08709.png',
#  'train\\Mild\\93be637084a2.png',
#  'train\\Mild\\94111ed3d276.png',
#  'train\\Mild\\94372043d55b.png',
#  'train\\Mild\\944a233fbf8e.png',
#  'train\\Mild\\94b1d8ad35ec.png',
#  'train\\Mild\\95a4cc805c7b.png',
#  'train\\Mild\\96a9706b8534.png',
#  'train\\Mild\\977e1ca77653.png',
#  'train\\Mild\\9782c0489eca.png',
#  'train\\Mild\\98fbe56dcc2c.png',
#  'train\\Mild\\99132193eaa0.png',
#  'train\\Mild\\99ecdb41d5e7.png',
#  'train\\Mild\\9a3109657ac1.png',
#  'train\\Mild\\9eaf735cf01f.png',
#  'train\\Mild\\9ed666e982cd.png',
#  'train\\Mild\\a00b4cb250a7.png',
#  'train\\Mild\\a01024054596.png',
#  'train\\Mild\\a19ecd0a706e.png',
#  'train\\Mild\\a2696f444ecb.png',
#  'train\\Mild\\a28bfb772f50.png',
#  'train\\Mild\\a32886cb31ab.png',
#  'train\\Mild\\a3ad6c2db6f1.png',
#  'train\\Mild\\a3d2a0c4cd17.png',
#  'train\\Mild\\a443c4fd489c.png',
#  'train\\Mild\\a47432cd41e7.png',
#  'train\\Mild\\a5a2a7003d60.png',
#  'train\\Mild\\a75bab2463d4.png',
#  'train\\Mild\\a77dbec966d4.png',
#  'train\\Mild\\a7ec056502e7.png',
#  'train\\Mild\\a8582e346df0.png',
#  'train\\Mild\\a8c54e2a4b79.png',
#  'train\\Mild\\a8c950a99107.png',
#  'train\\Mild\\a95858e052d6.png',
#  'train\\Mild\\ababe19ed448.png',
#  'train\\Mild\\abdb365cacbc.png',
#  'train\\Mild\\ad1f7445b1a8.png',
#  'train\\Mild\\ad3fc5076852.png',
#  'train\\Mild\\ae8472f8d310.png',
#  'train\\Mild\\af133a85ea0c.png',
#  'train\\Mild\\b07bc463b718.png',
#  'train\\Mild\\b1197f2cc9b3.png',
#  'train\\Mild\\b17f0b81dab3.png',
#  'train\\Mild\\b22354b5f94b.png',
#  'train\\Mild\\b4f41b5bf0ef.png',
#  'train\\Mild\\b50b30aa6e6c.png',
#  'train\\Mild\\b56340f472d2.png',
#  'train\\Mild\\b576c5269ad1.png',
#  'train\\Mild\\b640e3bdff75.png',
#  'train\\Mild\\b6a0e348a01e.png',
#  'train\\Mild\\b71428739d4e.png',
#  'train\\Mild\\b7278b4f2448.png',
#  'train\\Mild\\b8ebedd382de.png',
#  'train\\Mild\\b94c58d063bf.png',
#  'train\\Mild\\b9b99dad668d.png',
#  'train\\Mild\\bacfb1029f6b.png',
#  'train\\Mild\\bb11db08584a.png',
#  'train\\Mild\\bb45257258cc.png',
#  'train\\Mild\\bb783d8e496f.png',
#  'train\\Mild\\bb9a3d835a94.png',
#  'train\\Mild\\bc73ce76ec43.png',
#  'train\\Mild\\bd269a1f0e4d.png',
#  'train\\Mild\\bebb3f167654.png',
#  'train\\Mild\\bf18ff30a8f6.png',
#  'train\\Mild\\c027e5482e8c.png',
#  'train\\Mild\\c0968d41eb93.png',
#  'train\\Mild\\c0e15e8e2b46.png',
#  'train\\Mild\\c0f15fe3b4b7.png',
#  'train\\Mild\\c102db7634d8.png',
#  'train\\Mild\\c1e6fa1ad314.png',
#  'train\\Mild\\c1ebe785503a.png',
#  'train\\Mild\\c40976189f22.png',
#  'train\\Mild\\c4a8f2fcf6e8.png',
#  'train\\Mild\\c56e65f74187.png',
#  'train\\Mild\\c739ff9580d3.png',
#  'train\\Mild\\c7b622ec8104.png',
#  'train\\Mild\\c8fc0df22999.png',
#  'train\\Mild\\c9485c38fdd5.png',
#  'train\\Mild\\c96f743915b5.png',
#  'train\\Mild\\ca1036496659.png',
#  'train\\Mild\\ca25745942b0.png',
#  'train\\Mild\\ca30a97e9d13.png',
#  'train\\Mild\\ca63fe4f4b52.png',
#  'train\\Mild\\ca6842bfcbc9.png',
#  'train\\Mild\\ca7140ecf389.png',
#  'train\\Mild\\cab3dfa7962d.png',
#  'train\\Mild\\cae51154e1ce.png',
#  'train\\Mild\\cb2f3c5d71a7.png',
#  'train\\Mild\\cc12453ea915.png',
#  'train\\Mild\\cc9270f06b65.png',
#  'train\\Mild\\cd45bfa07d41.png',
#  'train\\Mild\\cd5714db652d.png',
#  'train\\Mild\\cf0575534cec.png',
#  'train\\Mild\\cf603a9ef2d5.png',
#  'train\\Mild\\cfd1bd0fcbb4.png',
#  'train\\Mild\\d06ccd0cf4b8.png',
#  'train\\Mild\\d0d59ed675b5.png',
#  'train\\Mild\\d1cad012a254.png',
#  'train\\Mild\\d3de0d313d61.png',
#  'train\\Mild\\d4f32b9c07df.png',
#  'train\\Mild\\d567a1a22d33.png',
#  'train\\Mild\\d5b4705ac2ee.png',
#  'train\\Mild\\d66b6f333dc7.png',
#  'train\\Mild\\d66ccb75ada1.png',
#  'train\\Mild\\d6e26fe51dce.png',
#  'train\\Mild\\d801c0a66738.png',
#  'train\\Mild\\d85588ff2ebd.png',
#  'train\\Mild\\d85d052900b4.png',
#  'train\\Mild\\da1fb35f5df9.png',
#  'train\\Mild\\db4ed1e07aa3.png',
#  'train\\Mild\\db690e2d02f8.png',
#  'train\\Mild\\dbd062558b81.png',
#  'train\\Mild\\dd19428c3d29.png',
#  'train\\Mild\\e07045d7c5f7.png',
#  'train\\Mild\\e25ccfe38e44.png',
#  'train\\Mild\\e26d8718ca58.png',
#  'train\\Mild\\e2a233493b90.png',
#  'train\\Mild\\e38f3a65b02b.png',
#  'train\\Mild\\e55188915f9d.png',
#  'train\\Mild\\e580676516b0.png',
#  'train\\Mild\\e9286ddf6ffe.png',
#  'train\\Mild\\e96bd80a8a53.png',
#  'train\\Mild\\e9ff9352ccb3.png',
#  'train\\Mild\\ea15a290eb96.png',
#  'train\\Mild\\ead23cc922ed.png',
#  'train\\Mild\\eba3acc42197.png',
#  'train\\Mild\\ec4649213ccf.png',
#  'train\\Mild\\ee78ce914066.png',
#  'train\\Mild\\eeb231c3ef1f.png',
#  'train\\Mild\\eed4afc8ec83.png',
#  'train\\Mild\\ef8109305128.png',
#  'train\\Mild\\f0c13be90519.png',
#  'train\\Mild\\f47a2a4a0411.png',
#  'train\\Mild\\f481f76a6b75.png',
#  'train\\Mild\\f55e1d2a19e4.png',
#  'train\\Mild\\f5650eb52640.png',
#  'train\\Mild\\f6f7dba7104d.png',
#  'train\\Mild\\f72ef9ceeaa8.png',
#  'train\\Mild\\f762c272c522.png',
#  'train\\Mild\\f7fec8935126.png',
#  'train\\Mild\\fb6b8200b7f8.png',
#  'train\\Mild\\fca931da5c5e.png',
#  'train\\Mild\\fd62bd0db4f1.png',
#  'train\\Mild\\fdd18ccbbdc5.png',
#  'train\\Mild\\fe2df69676cf.png',
#  'train\\Mild\\fe674c2f73f5.png',
#  'train\\Mild\\fea14b3d44b0.png',
#  'train\\Mild\\fecf4c5ae84b.png',
#  'train\\Moderate\\000c1434d8d7.png',
#  'train\\Moderate\\00a8624548a9.png',
#  'train\\Moderate\\00b74780d31d.png',
#  'train\\Moderate\\00e4ddff966a.png',
#  'train\\Moderate\\012a242ac6ff.png',
#  'train\\Moderate\\0161338f53cc.png',
#  'train\\Moderate\\0180bfa26c0b.png',
#  'train\\Moderate\\01c7808d901d.png',
#  'train\\Moderate\\01eb826f6467.png',
#  'train\\Moderate\\025a169a0bb0.png',
#  'train\\Moderate\\026dcd9af143.png',
#  'train\\Moderate\\032d7b0b4bf6.png',
#  'train\\Moderate\\033f2b43de6d.png',
#  'train\\Moderate\\03676c71ed1b.png',
#  'train\\Moderate\\03747397839f.png',
#  'train\\Moderate\\03fd50da928d.png',
#  'train\\Moderate\\03ff7d159f10.png',
#  'train\\Moderate\\0415fc68b176.png',
#  'train\\Moderate\\041f09eec1e8.png',
#  'train\\Moderate\\04a6fc58dabc.png',
#  'train\\Moderate\\04d029cfb612.png',
#  'train\\Moderate\\0519b934f6b1.png',
#  'train\\Moderate\\052d9a3fe55a.png',
#  'train\\Moderate\\06024377d573.png',
#  'train\\Moderate\\064af6592ba6.png',
#  'train\\Moderate\\07083738b75e.png',
#  'train\\Moderate\\071435a218ec.png',
#  'train\\Moderate\\07419eddd6be.png',
#  'train\\Moderate\\07a3be30563b.png',
#  'train\\Moderate\\07d8db76b301.png',
#  'train\\Moderate\\08752092140d.png',
#  'train\\Moderate\\08c17a2d95b7.png',
#  'train\\Moderate\\094858f005ab.png',
#  'train\\Moderate\\0953c0ac1735.png',
#  'train\\Moderate\\09eeafa9656a.png',
#  'train\\Moderate\\09f6ab477654.png',
#  'train\\Moderate\\0a09aa7356c0.png',
#  'train\\Moderate\\0a1076183736.png',
#  'train\\Moderate\\0a9ec1e99ce4.png',
#  'train\\Moderate\\0ac436400db4.png',
#  'train\\Moderate\\0af296d2f04a.png',
#  'train\\Moderate\\0afdfe5f422c.png',
#  'train\\Moderate\\0c2e2369dfff.png',
#  'train\\Moderate\\0c55d58bebaf.png',
#  'train\\Moderate\\0c76fd494af6.png',
#  'train\\Moderate\\0c7e82daf5a0.png',
#  'train\\Moderate\\0ca0aee4d57e.png',
#  'train\\Moderate\\0d0a21fd354f.png',
#  'train\\Moderate\\0da09e3ce8f1.png',
#  'train\\Moderate\\0dbaa09a458c.png',
#  'train\\Moderate\\0e75d51152fc.png',
#  'train\\Moderate\\0efc93ec838b.png',
#  'train\\Moderate\\0eff8eacb2f7.png',
#  'train\\Moderate\\0fb560f9adb2.png',
#  'train\\Moderate\\0fcfc6301f3d.png',
#  'train\\Moderate\\0fd16b64697e.png',
#  'train\\Moderate\\0fffa73e2402.png',
#  'train\\Moderate\\1006345f70b7.png',
#  'train\\Moderate\\10ecc5292ab1.png',
#  'train\\Moderate\\10eefba568dd.png',
#  'train\\Moderate\\1120f6d08d95.png',
#  'train\\Moderate\\1124ffcd76c2.png',
#  'train\\Moderate\\115e42dd6a81.png',
#  'train\\Moderate\\1177d583c807.png',
#  'train\\Moderate\\11b5c77fbf79.png',
#  'train\\Moderate\\12025b34deb8.png',
#  'train\\Moderate\\1269ab57c2e6.png',
#  'train\\Moderate\\12a82fc7d73e.png',
#  'train\\Moderate\\12e6e66c80a7.png',
#  'train\\Moderate\\13063d1bc4ea.png',
#  'train\\Moderate\\135575dc57c9.png',
#  'train\\Moderate\\13d71389563f.png',
#  'train\\Moderate\\1411c8ab7161.png',
#  'train\\Moderate\\1414128bead0.png',
#  'train\\Moderate\\141735b57ec0.png',
#  'train\\Moderate\\1438288bb2e1.png',
#  'train\\Moderate\\144a1a426137.png',
#  'train\\Moderate\\144b01e7b993.png',
#  'train\\Moderate\\14515b8f19b6.png',
#  'train\\Moderate\\14ee87d6cc42.png',
#  'train\\Moderate\\1541226c5d72.png',
#  'train\\Moderate\\15528e740543.png',
#  'train\\Moderate\\157d17349cc6.png',
#  'train\\Moderate\\1594ca6c30d3.png',
#  'train\\Moderate\\15cd5f52d300.png',
#  'train\\Moderate\\1632c4311fc9.png',
#  'train\\Moderate\\17188c13e635.png',
#  'train\\Moderate\\175dd560810a.png',
#  'train\\Moderate\\17eb5d4ad740.png',
#  'train\\Moderate\\180afe1d5ef7.png',
#  'train\\Moderate\\18323d8f2470.png',
#  'train\\Moderate\\1844a039b4ea.png',
#  'train\\Moderate\\188a9323be03.png',
#  'train\\Moderate\\18af532e7e1e.png',
#  'train\\Moderate\\18d8fdb140b7.png',
#  'train\\Moderate\\18f1f979d30d.png',
#  'train\\Moderate\\19113e5f45ec.png',
#  'train\\Moderate\\191348830ddf.png',
#  'train\\Moderate\\1943983492e5.png',
#  'train\\Moderate\\1968183f0e61.png',
#  'train\\Moderate\\196e6a186452.png',
#  'train\\Moderate\\1a1b4b2450ca.png',
#  'train\\Moderate\\1a369baf9ee6.png',
#  'train\\Moderate\\1ade1e949383.png',
#  'train\\Moderate\\1ae8c165fd53.png',
#  'train\\Moderate\\1b4625877527.png',
#  'train\\Moderate\\1b8ad0afe9fb.png',
#  'train\\Moderate\\1bea04b2bb2d.png',
#  'train\\Moderate\\1c0e5dd1b14c.png',
#  'train\\Moderate\\1c4d87baaffc.png',
#  'train\\Moderate\\1c578b72d7b3.png',
#  'train\\Moderate\\1c5ad36fb799.png',
#  'train\\Moderate\\1c5e6cdc7ee1.png',
#  'train\\Moderate\\1c6d119c3d70.png',
#  'train\\Moderate\\1cb814ed6332.png',
#  'train\\Moderate\\1d14dd912671.png',
#  'train\\Moderate\\1d55e689cf84.png',
#  'train\\Moderate\\1da25637859b.png',
#  'train\\Moderate\\1db18bdd43aa.png',
#  'train\\Moderate\\1dbdc32c17db.png',
#  'train\\Moderate\\1dd9adcbfff4.png',
#  'train\\Moderate\\1dfbede13143.png',
#  'train\\Moderate\\1e143fa3de57.png',
#  'train\\Moderate\\1e1fb019710d.png',
#  'train\\Moderate\\1e4650743fa2.png',
#  'train\\Moderate\\1e4b3b823b95.png',
#  'train\\Moderate\\1ee1eb7943db.png',
#  'train\\Moderate\\1f07dae3cadb.png',
#  'train\\Moderate\\1f0e223b8055.png',
#  'train\\Moderate\\1f4bf8e28b41.png',
#  'train\\Moderate\\1f543a86c4d4.png',
#  'train\\Moderate\\1f63d44d9e3c.png',
#  'train\\Moderate\\1ffaa51a6245.png',
#  'train\\Moderate\\203275daf46d.png',
#  'train\\Moderate\\20404ec7b518.png',
#  'train\\Moderate\\20688cb25704.png',
#  'train\\Moderate\\207a580de0ea.png',
#  'train\\Moderate\\20c883d3bd38.png',
#  'train\\Moderate\\2131aa3a1e6f.png',
#  'train\\Moderate\\217dad18a5ed.png',
#  'train\\Moderate\\222d0ac042b4.png',
#  'train\\Moderate\\2241b7e90782.png',
#  'train\\Moderate\\224bb938e2dd.png',
#  'train\\Moderate\\22ce8ef69357.png',
#  'train\\Moderate\\23148a40ecb0.png',
#  'train\\Moderate\\23175b7ef453.png',
#  'train\\Moderate\\232549883508.png',
#  'train\\Moderate\\234399352d36.png',
#  'train\\Moderate\\236f56771ec6.png',
#  'train\\Moderate\\2376e5415458.png',
#  'train\\Moderate\\239f2c348ea4.png',
#  'train\\Moderate\\23d7ca170bdb.png',
#  'train\\Moderate\\23fca0693e2a.png',
#  'train\\Moderate\\2463bb04ebc3.png',
#  'train\\Moderate\\246e4506824a.png',
#  'train\\Moderate\\25002fe43f92.png',
#  'train\\Moderate\\2532613a584a.png',
#  'train\\Moderate\\25dc1b41ed9c.png',
#  'train\\Moderate\\2608e1dac5b1.png',
#  'train\\Moderate\\261c6bd63bff.png',
#  'train\\Moderate\\26453eb7e989.png',
#  'train\\Moderate\\26999ebc21de.png',
#  'train\\Moderate\\269f0792f11f.png',
#  'train\\Moderate\\26e231747848.png',
#  'train\\Moderate\\2700754f71e9.png',
#  'train\\Moderate\\272d9c043c81.png',
#  'train\\Moderate\\2735be026d44.png',
#  'train\\Moderate\\2776d70724d3.png',
#  'train\\Moderate\\27b68863349f.png',
#  'train\\Moderate\\27bab1432f61.png',
#  'train\\Moderate\\27fca9f12b3c.png',
#  'train\\Moderate\\282bc792d23a.png',
#  'train\\Moderate\\28824d12d31d.png',
#  'train\\Moderate\\28a4d00927b7.png',
#  'train\\Moderate\\28f93cad89c5.png',
#  'train\\Moderate\\290ecdba359f.png',
#  'train\\Moderate\\291e2ff3d834.png',
#  'train\\Moderate\\29580bed2f7d.png',
#  'train\\Moderate\\295fdc964f6e.png',
#  'train\\Moderate\\2967e578939f.png',
#  'train\\Moderate\\29f44aea93a4.png',
#  'train\\Moderate\\2a099b247b10.png',
#  'train\\Moderate\\2a3378bcfbcc.png',
#  'train\\Moderate\\2a3a1ed1c285.png',
#  'train\\Moderate\\2a47e5b21791.png',
#  'train\\Moderate\\2a5a8b744f08.png',
#  'train\\Moderate\\2af1bf226f51.png',
#  'train\\Moderate\\2b074afdf626.png',
#  'train\\Moderate\\2b07790a2422.png',
#  'train\\Moderate\\2b21d293fdf2.png',
#  'train\\Moderate\\2b88cb6e31cd.png',
#  'train\\Moderate\\2ba0b0d9bda2.png',
#  'train\\Moderate\\2bd4d4fbed5c.png',
#  'train\\Moderate\\2c1d5be654dd.png',
#  'train\\Moderate\\2c2aa057afc5.png',
#  'train\\Moderate\\2cbfc6182ba2.png',
#  'train\\Moderate\\2cceb07ff706.png',
#  'train\\Moderate\\2cef97083e6f.png',
#  'train\\Moderate\\2d552318eb07.png',
#  'train\\Moderate\\2d870833c0c9.png',
#  'train\\Moderate\\2e26762daed5.png',
#  'train\\Moderate\\2e79041ef722.png',
#  'train\\Moderate\\2f5c9cdfb333.png',
#  'train\\Moderate\\2f9b66784109.png',
#  'train\\Moderate\\2fb3a8606a77.png',
#  'train\\Moderate\\2fdffb6160a6.png',
#  'train\\Moderate\\300305ce82d2.png',
#  'train\\Moderate\\302bcdb635ff.png',
#  'train\\Moderate\\308f7fce6f0d.png',
#  'train\\Moderate\\310c27067ac0.png',
#  'train\\Moderate\\3128eb593012.png',
#  'train\\Moderate\\31452ad8808c.png',
#  'train\\Moderate\\314862758acf.png',
#  'train\\Moderate\\31b5d6fb0256.png',
#  'train\\Moderate\\3246f07e65b4.png',
#  'train\\Moderate\\32a3eb37ff40.png',
#  'train\\Moderate\\331b87d1b9d1.png',
#  'train\\Moderate\\33e8e26a75d4.png',
#  'train\\Moderate\\3402124408ea.png',
#  'train\\Moderate\\3428230bf1bd.png',
#  'train\\Moderate\\34723fae6475.png',
#  'train\\Moderate\\349f3c0ac83e.png',
#  'train\\Moderate\\354b8911d6ed.png',
#  'train\\Moderate\\362c4a96cebb.png',
#  'train\\Moderate\\367c7049929c.png',
#  'train\\Moderate\\36a1e3c780a0.png',
#  'train\\Moderate\\36ec36c301c1.png',
#  'train\\Moderate\\3748349334f6.png',
#  'train\\Moderate\\37de05ef12a5.png',
#  'train\\Moderate\\38487e1a5b1f.png',
#  'train\\Moderate\\388f12e8df0b.png',
#  'train\\Moderate\\38e111cac46f.png',
#  'train\\Moderate\\38fe9f854046.png',
#  'train\\Moderate\\39134907127a.png',
#  'train\\Moderate\\39923b29988a.png',
#  'train\\Moderate\\39b5b05d6cd9.png',
#  'train\\Moderate\\3a122851e526.png',
#  'train\\Moderate\\3a1d3ce00f0c.png',
#  'train\\Moderate\\3a61e690f4bb.png',
#  'train\\Moderate\\3aa2b1ce6700.png',
#  'train\\Moderate\\3b58b02c89ed.png',
#  'train\\Moderate\\3b9c1f42c2f2.png',
#  'train\\Moderate\\3c1efa38d0da.png',
#  'train\\Moderate\\3c311c9109b0.png',
#  'train\\Moderate\\3c53198519f7.png',
#  'train\\Moderate\\3cd801ffdbf0.png',
#  'train\\Moderate\\3cdda8b3df19.png',
#  'train\\Moderate\\3d3e288d490e.png',
#  'train\\Moderate\\3d663a6a50a3.png',
#  'train\\Moderate\\3dbfbc11e105.png',
#  'train\\Moderate\\3ddb86eb530e.png',
#  'train\\Moderate\\3dfc50108072.png',
#  'train\\Moderate\\3e1f8fecb06f.png',
#  'train\\Moderate\\3e6bfc4d5c65.png',
#  'train\\Moderate\\3e86335bc2fd.png',
#  'train\\Moderate\\3f3de2a6b0f5.png',
#  'train\\Moderate\\3f47f83217b5.png',
#  'train\\Moderate\\3f5b4c2948e8.png',
#  'train\\Moderate\\3f8d5c940ba4.png',
#  'train\\Moderate\\3fc219927a97.png',
#  'train\\Moderate\\3fd7df6099e3.png',
#  'train\\Moderate\\3ffa14d60b24.png',
#  'train\\Moderate\\40140a925c43.png',
#  'train\\Moderate\\40527a5e95dd.png',
#  'train\\Moderate\\417f408ee8e0.png',
#  'train\\Moderate\\4189d4e631ec.png',
#  'train\\Moderate\\419406328dcd.png',
#  'train\\Moderate\\423abbaa5fad.png',
#  'train\\Moderate\\4242c0d87f57.png',
#  'train\\Moderate\\4246ed634f25.png',
#  'train\\Moderate\\4289af3afbd2.png',
#  'train\\Moderate\\42a67337fa8e.png',
#  'train\\Moderate\\42a850acd2ac.png',
#  'train\\Moderate\\42b08dca9b2f.png',
#  'train\\Moderate\\42b93b574f23.png',
#  'train\\Moderate\\435d900fa7b2.png',
#  'train\\Moderate\\436e1793d240.png',
#  'train\\Moderate\\437900a99871.png',
#  'train\\Moderate\\437cbec4a3f8.png',
#  'train\\Moderate\\4384fa687afa.png',
#  'train\\Moderate\\43ddd0ab0cc4.png',
#  'train\\Moderate\\43fb6eda9b97.png',
#  'train\\Moderate\\441117562359.png',
#  'train\\Moderate\\441affbe99aa.png',
#  'train\\Moderate\\4478b870e549.png',
#  'train\\Moderate\\44855f666225.png',
#  'train\\Moderate\\4489d421e5aa.png',
#  'train\\Moderate\\44c869174e3a.png',
#  'train\\Moderate\\44e0d56e9d42.png',
#  'train\\Moderate\\44e951e45dca.png',
#  'train\\Moderate\\44f4ae58990e.png',
#  'train\\Moderate\\453a1e2754b2.png',
#  'train\\Moderate\\453d553b0a94.png',
#  'train\\Moderate\\45ae04cfde5d.png',
#  'train\\Moderate\\45c39ab9e797.png',
#  'train\\Moderate\\460893cd86e3.png',
#  'train\\Moderate\\465c618f7b23.png',
#  'train\\Moderate\\467b7d9d811c.png',
#  'train\\Moderate\\46923eea9a4e.png',
#  'train\\Moderate\\46c1548d730e.png',
#  'train\\Moderate\\46f56c38051f.png',
#  'train\\Moderate\\475c7ded0f7a.png',
#  'train\\Moderate\\47b756014447.png',
#  'train\\Moderate\\47e51065b819.png',
#  'train\\Moderate\\4818672273af.png',
#  'train\\Moderate\\48543037d0b3.png',
#  'train\\Moderate\\48afe8c47454.png',
#  'train\\Moderate\\48c49f662f7d.png',
#  'train\\Moderate\\48c72dec46e5.png',
#  'train\\Moderate\\48fda42bd5d4.png',
#  'train\\Moderate\\49419f8d5cb4.png',
#  'train\\Moderate\\49a4765f8822.png',
#  'train\\Moderate\\49d69c4c6290.png',
#  'train\\Moderate\\4a0890b08532.png',
#  'train\\Moderate\\4a0bba3b7d83.png',
#  'train\\Moderate\\4a44cc840ebe.png',
#  'train\\Moderate\\4a558a1cd243.png',
#  'train\\Moderate\\4ad6109706e8.png',
#  'train\\Moderate\\4b1001050f1d.png',
#  'train\\Moderate\\4b422b48d0d4.png',
#  'train\\Moderate\\4b5ffea77373.png',
#  'train\\Moderate\\4c52922f3bfd.png',
#  'train\\Moderate\\4c78d9d18da9.png',
#  'train\\Moderate\\4ce74e5eb51d.png',
#  'train\\Moderate\\4d009cebabc9.png',
#  'train\\Moderate\\4d1cf360b2d7.png',
#  'train\\Moderate\\4d21ce39c905.png',
#  'train\\Moderate\\4da6e2089d57.png',
#  'train\\Moderate\\4dbce359d0e1.png',
#  'train\\Moderate\\4e43d05cc2ef.png',
#  'train\\Moderate\\4e7694eebb91.png',
#  'train\\Moderate\\4ed31cc07366.png',
#  'train\\Moderate\\4ee1ad981a6d.png',
#  'train\\Moderate\\4ef0b485a7da.png',
#  'train\\Moderate\\4f20f9a9a65b.png',
#  'train\\Moderate\\4f46d7ee61ed.png',
#  'train\\Moderate\\4f60129e9a5b.png',
#  'train\\Moderate\\50d8a8fb7737.png',
#  'train\\Moderate\\51030843fde2.png',
#  'train\\Moderate\\510aa0a898fa.png',
#  'train\\Moderate\\51405d042000.png',
#  'train\\Moderate\\5152bf091152.png',
#  'train\\Moderate\\5173d54fc214.png',
#  'train\\Moderate\\5188a8afa879.png',
#  'train\\Moderate\\51cfeccaf40d.png',
#  'train\\Moderate\\51d0034d177d.png',
#  'train\\Moderate\\51d574513bcb.png',
#  'train\\Moderate\\51d780864365.png',
#  'train\\Moderate\\521d3e264d71.png',
#  'train\\Moderate\\52230bbef30e.png',
#  'train\\Moderate\\523d0c2cb4d6.png',
#  'train\\Moderate\\523ff163211b.png',
#  'train\\Moderate\\524f240e0c90.png',
#  'train\\Moderate\\525acfea47e8.png',
#  'train\\Moderate\\5265dc9acdf8.png',
#  'train\\Moderate\\527bea76116c.png',
#  'train\\Moderate\\52886bed8a07.png',
#  'train\\Moderate\\52dbec057cc8.png',
#  'train\\Moderate\\530d78467615.png',
#  'train\\Moderate\\5327f88a1919.png',
#  'train\\Moderate\\541db13517e2.png',
#  'train\\Moderate\\547b37da9223.png',
#  'train\\Moderate\\5486da4273d7.png',
#  'train\\Moderate\\54bbe3da103e.png',
#  'train\\Moderate\\54cab3596214.png',
#  'train\\Moderate\\54dc6e8107cd.png',
#  'train\\Moderate\\55034b1dbff2.png',
#  'train\\Moderate\\55092c0071eb.png',
#  'train\\Moderate\\55fd453001cc.png',
#  'train\\Moderate\\56e56aa08362.png',
#  'train\\Moderate\\5723d0ec895e.png',
#  'train\\Moderate\\57469423a012.png',
#  'train\\Moderate\\57760be09c03.png',
#  'train\\Moderate\\57a5f1015504.png',
#  'train\\Moderate\\57ce57a8cfb0.png',
#  'train\\Moderate\\57f933d3d7c7.png',
#  'train\\Moderate\\582f739b8f62.png',
#  'train\\Moderate\\58529a8638d0.png',
#  'train\\Moderate\\5905a9b06a73.png',
#  'train\\Moderate\\594f69b503ad.png',
#  'train\\Moderate\\599b89048034.png',
#  'train\\Moderate\\59ee65760535.png',
#  'train\\Moderate\\59f3f70abddd.png',
#  'train\\Moderate\\5a03fe3ed15c.png',
#  'train\\Moderate\\5a11d21c2828.png',
#  'train\\Moderate\\5a2c27b95c7c.png',
#  'train\\Moderate\\5a36cea278ae.png',
#  'train\\Moderate\\5a5d3798c357.png',
#  'train\\Moderate\\5b301a6d1ac7.png',
#  'train\\Moderate\\5b644a403e1f.png',
#  'train\\Moderate\\5c6194562ed2.png',
#  'train\\Moderate\\5c8482926a08.png',
#  'train\\Moderate\\5cc6dea19614.png',
#  'train\\Moderate\\5cde55f745af.png',
#  'train\\Moderate\\5cf9127f251a.png',
#  'train\\Moderate\\5d024177e214.png',
#  'train\\Moderate\\5dc23e440de3.png',
#  'train\\Moderate\\5e18af29d812.png',
#  'train\\Moderate\\5e52c9fe676f.png',
#  'train\\Moderate\\5e7630f8438e.png',
#  'train\\Moderate\\5e7cc6ab4ac4.png',
#  'train\\Moderate\\5eb311bcb5f9.png',
#  'train\\Moderate\\5ed6dc419e4d.png',
#  'train\\Moderate\\5f70ad48a525.png',
#  'train\\Moderate\\60e269e3e188.png',
#  'train\\Moderate\\60eeae3ba23d.png',
#  'train\\Moderate\\61ac9b0dc6b9.png',
#  'train\\Moderate\\61c2fbd16e38.png',
#  'train\\Moderate\\624fb7317106.png',
#  'train\\Moderate\\62ab144d5cee.png',
#  'train\\Moderate\\62cc7ddb53b6.png',
#  'train\\Moderate\\62e6f814c8f5.png',
#  'train\\Moderate\\62ecdc90dd42.png',
#  'train\\Moderate\\6363b360aefb.png',
#  'train\\Moderate\\63c3c571b8ee.png',
#  'train\\Moderate\\63d217b059b6.png',
#  'train\\Moderate\\64a13949e879.png',
#  'train\\Moderate\\650fbed3fdca.png',
#  'train\\Moderate\\6531070bf03c.png',
#  'train\\Moderate\\653534ded339.png',
#  'train\\Moderate\\657859f893d9.png',
#  'train\\Moderate\\65e530ee2e79.png',
#  'train\\Moderate\\663a923d5398.png',
#  'train\\Moderate\\6666c4f18396.png',
#  'train\\Moderate\\668e853258cd.png',
#  'train\\Moderate\\66bae1ba227f.png',
#  'train\\Moderate\\66d2ca47aa44.png',
#  'train\\Moderate\\6733544ae7a6.png',
#  'train\\Moderate\\674057ab250c.png',
#  'train\\Moderate\\67844c46bc61.png',
#  'train\\Moderate\\67c03349bb31.png',
#  'train\\Moderate\\6810410187a0.png',
#  'train\\Moderate\\681c3c115684.png',
#  'train\\Moderate\\686ed1dbae20.png',
#  'train\\Moderate\\6889bc64ab09.png',
#  'train\\Moderate\\69591ebb198d.png',
#  'train\\Moderate\\6987804eb464.png',
#  'train\\Moderate\\698d6e422a80.png',
#  'train\\Moderate\\69df7ade0575.png',
#  'train\\Moderate\\6a91eb157f47.png',
#  'train\\Moderate\\6b7cf869622a.png',
#  'train\\Moderate\\6b869f37cdf3.png',
#  'train\\Moderate\\6ba5ed791444.png',
#  'train\\Moderate\\6c2555a9cae4.png',
#  'train\\Moderate\\6c315ad3d07f.png',
#  'train\\Moderate\\6cb98da77e3e.png',
#  'train\\Moderate\\6cbc3dad809c.png',
#  'train\\Moderate\\6d3d1fe6c32a.png',
#  'train\\Moderate\\6d454444f17c.png',
#  'train\\Moderate\\6dcde47060f9.png',
#  'train\\Moderate\\6dfd80748e72.png',
#  'train\\Moderate\\6e092b306fe1.png',
#  'train\\Moderate\\6e68e742f5bc.png',
#  'train\\Moderate\\6f0463c1ff18.png',
#  'train\\Moderate\\6f4e0538d1e4.png',
#  'train\\Moderate\\709784f7fcc2.png',
#  'train\\Moderate\\70ed3ec68b94.png',
#  'train\\Moderate\\70f5caf5f305.png',
#  'train\\Moderate\\7102f29e052e.png',
#  'train\\Moderate\\711d1480d2e3.png',
#  'train\\Moderate\\71e4130bf5c8.png',
#  'train\\Moderate\\7247a2c97f71.png',
#  'train\\Moderate\\731b19a460ad.png',
#  'train\\Moderate\\7350c50667c5.png',
#  'train\\Moderate\\7356dd08b0ae.png',
#  'train\\Moderate\\73e83a07a16d.png',
#  'train\\Moderate\\74418f620068.png',
#  'train\\Moderate\\7455e2b5fc57.png',
#  'train\\Moderate\\7550966ef777.png',
#  'train\\Moderate\\757572337fd0.png',
#  'train\\Moderate\\75a7bc945b7d.png',
#  'train\\Moderate\\760b6f4c6d82.png',
#  'train\\Moderate\\7663aba8d762.png',
#  'train\\Moderate\\76c0c7e1b6cb.png',
#  'train\\Moderate\\76cfe8967f7d.png',
#  'train\\Moderate\\76e6a9238570.png',
#  'train\\Moderate\\76fe19ff64fb.png',
#  'train\\Moderate\\7743f4e04a6d.png',
#  'train\\Moderate\\77543f66a84a.png',
#  'train\\Moderate\\77baa08a1345.png',
#  'train\\Moderate\\77e7c7a160c8.png',
#  'train\\Moderate\\77f69c7ff324.png',
#  'train\\Moderate\\7877be80901c.png',
#  'train\\Moderate\\78a577c3e0bf.png',
#  'train\\Moderate\\78d53c82a23e.png',
#  'train\\Moderate\\79059d0592c4.png',
#  'train\\Moderate\\79540be95177.png',
#  'train\\Moderate\\799cb4c816ae.png',
#  'train\\Moderate\\79be2ff796bf.png',
#  'train\\Moderate\\7a0cff4c24b2.png',
#  'train\\Moderate\\7b8c78b41c0d.png',
#  'train\\Moderate\\7bc2e0fa3f72.png',
#  'train\\Moderate\\7bda86d95c5b.png',
#  'train\\Moderate\\7c2f820a6425.png',
#  'train\\Moderate\\7c52fe73e748.png',
#  'train\\Moderate\\7d1b40fdbd86.png',
#  'train\\Moderate\\7d1da90d3ca9.png',
#  'train\\Moderate\\7d261f986bef.png',
#  'train\\Moderate\\7d37a2939f12.png',
#  'train\\Moderate\\7d8f67cadc29.png',
#  'train\\Moderate\\7dee6bf8b9c1.png',
#  'train\\Moderate\\7e6e90a93aa5.png',
#  'train\\Moderate\\7e9458de5707.png',
#  'train\\Moderate\\7ec1ffe8220b.png',
#  'train\\Moderate\\7f6ce40f306b.png',
#  'train\\Moderate\\7f84284598f5.png',
#  'train\\Moderate\\8000a6b97a84.png',
#  'train\\Moderate\\803120c5d287.png',
#  'train\\Moderate\\807135cbc438.png',
#  'train\\Moderate\\80b5a9519aec.png',
#  'train\\Moderate\\80feb1f7ca5e.png',
#  'train\\Moderate\\812d5adafaf2.png',
#  'train\\Moderate\\81b0a2651c45.png',
#  'train\\Moderate\\81bc03e2ff2b.png',
#  'train\\Moderate\\82910bba4753.png',
#  'train\\Moderate\\82deb07a6618.png',
#  'train\\Moderate\\82f2784ead76.png',
#  'train\\Moderate\\83b61051737f.png',
#  'train\\Moderate\\83d6e40c869f.png',
#  'train\\Moderate\\840527bc6628.png',
#  'train\\Moderate\\8421107255ae.png',
#  'train\\Moderate\\842d697884f6.png',
#  'train\\Moderate\\8446826853d0.png',
#  'train\\Moderate\\84e8c62165b5.png',
#  'train\\Moderate\\8543a801dce0.png',
#  'train\\Moderate\\855f0a5442b6.png',
#  'train\\Moderate\\857002ed4e49.png',
#  'train\\Moderate\\85cc6d636898.png',
#  'train\\Moderate\\85fce24084da.png',
#  'train\\Moderate\\86722fcd802c.png',
#  'train\\Moderate\\869bbd3170cc.png',
#  'train\\Moderate\\86b3a7929bec.png',
#  'train\\Moderate\\86baef833ae0.png',
#  'train\\Moderate\\86e7f98f73f1.png',
#  'train\\Moderate\\86fbac86ed3e.png',
#  'train\\Moderate\\873fe0404d6e.png',
#  'train\\Moderate\\876e1dd12d38.png',
#  'train\\Moderate\\878a3a097436.png',
#  'train\\Moderate\\879744b9dc65.png',
#  'train\\Moderate\\87b1938994b5.png',
#  'train\\Moderate\\882a71de424e.png',
#  'train\\Moderate\\8860c7b11530.png',
#  'train\\Moderate\\8871e6a26596.png',
#  'train\\Moderate\\891392c9683c.png',
#  'train\\Moderate\\89b044cbaf85.png',
#  'train\\Moderate\\89b725411cee.png',
#  'train\\Moderate\\89d2a7403a06.png',
#  'train\\Moderate\\89ee1fa16f90.png',
#  'train\\Moderate\\89fc080f7e83.png',
#  'train\\Moderate\\8a67f1efa315.png',
#  'train\\Moderate\\8a759f94613a.png',
#  'train\\Moderate\\8aab201c0691.png',
#  'train\\Moderate\\8ab8d9b3ce3f.png',
#  'train\\Moderate\\8acffaf1f4b9.png',
#  'train\\Moderate\\8b26d3cd61e8.png',
#  'train\\Moderate\\8bdb891661a8.png',
#  'train\\Moderate\\8c87bd748996.png',
#  'train\\Moderate\\8cb6b0efaaac.png',
#  'train\\Moderate\\8cb6b5b2f19c.png',
#  'train\\Moderate\\8d3d67661620.png',
#  'train\\Moderate\\8d62ba9cb22a.png',
#  'train\\Moderate\\8d7bb0649a02.png',
#  'train\\Moderate\\8dba09a4e5ed.png',
#  'train\\Moderate\\8dfa629ca74e.png',
#  'train\\Moderate\\8dfff47b06b7.png',
#  'train\\Moderate\\8e20b8fac7c3.png',
#  'train\\Moderate\\8e3b79e1f1f7.png',
#  'train\\Moderate\\8e63fc4ab532.png',
#  'train\\Moderate\\8eb3337a54e9.png',
#  'train\\Moderate\\8f1e7433a95d.png',
#  'train\\Moderate\\8ff2733f6aef.png',
#  'train\\Moderate\\9033f1493da1.png',
#  'train\\Moderate\\9041eb43456e.png',
#  'train\\Moderate\\907aaff827e5.png',
#  'train\\Moderate\\913b1890ed1e.png',
#  'train\\Moderate\\917f76f360b6.png',
#  'train\\Moderate\\91a88d3b0358.png',
#  'train\\Moderate\\91cbe1c775ef.png',
#  'train\\Moderate\\91e2c2890c9f.png',
#  'train\\Moderate\\91e8af9ceee9.png',
#  'train\\Moderate\\921433215353.png',
#  'train\\Moderate\\929cd3867815.png',
#  'train\\Moderate\\92b0d27fc0ec.png',
#  'train\\Moderate\\92d8a7c8e718.png',
#  'train\\Moderate\\92f313287a29.png',
#  'train\\Moderate\\932181b93b2f.png',
#  'train\\Moderate\\94a67ec0714f.png',
#  'train\\Moderate\\94dcb491143f.png',
#  'train\\Moderate\\9568eb7e9c08.png',
#  'train\\Moderate\\959dc602febc.png',
#  'train\\Moderate\\962cf85e4f6d.png',
#  'train\\Moderate\\96c3e3db68bc.png',
#  'train\\Moderate\\96d48b073f18.png',
#  'train\\Moderate\\975252e325e3.png',
#  'train\\Moderate\\9785805af1b8.png',
#  'train\\Moderate\\97a5ad7548b7.png',
#  'train\\Moderate\\97bf61736b86.png',
#  'train\\Moderate\\98104c8c67eb.png',
#  'train\\Moderate\\9837048b85dc.png',
#  'train\\Moderate\\98e8adcf085c.png',
#  'train\\Moderate\\98f48850ebce.png',
#  'train\\Moderate\\98f7136d2e7a.png',
#  'train\\Moderate\\9904939ab83d.png',
#  'train\\Moderate\\999115d9386b.png',
#  'train\\Moderate\\99e8bf998285.png',
#  'train\\Moderate\\9a28d4e8aef0.png',
#  'train\\Moderate\\9a3c03a5ad0f.png',
#  'train\\Moderate\\9a4f370d341b.png',
#  'train\\Moderate\\9a78c6a7b1c2.png',
#  'train\\Moderate\\9a7bd084395e.png',
#  'train\\Moderate\\9a9b21215c55.png',
#  'train\\Moderate\\9ad92f1c1542.png',
#  'train\\Moderate\\9b0eb9f41da4.png',
#  'train\\Moderate\\9b32e8ef0ca0.png',
#  'train\\Moderate\\9b418ce42c13.png',
#  'train\\Moderate\\9b7b6e4db1d5.png',
#  'train\\Moderate\\9b95d6203406.png',
#  'train\\Moderate\\9c088d2d1559.png',
#  'train\\Moderate\\9c5dd3612f0c.png',
#  'train\\Moderate\\9cedf5c7016b.png',
#  'train\\Moderate\\9d74428188bb.png',
#  'train\\Moderate\\9d98a0b585f2.png',
#  'train\\Moderate\\9d9bfefa809c.png',
#  'train\\Moderate\\9da74370835a.png',
#  'train\\Moderate\\9dab2e6ba44b.png',
#  'train\\Moderate\\9df31421cdd2.png',
#  'train\\Moderate\\9e5ec293267c.png',
#  'train\\Moderate\\9eaac43744f5.png',
#  'train\\Moderate\\9f1efb799b7b.png',
#  'train\\Moderate\\9f4132bd6ed6.png',
#  ...]

# %%
label
# Out:
# ['Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Mild',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  'Moderate',
#  ...]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({'Category': label})

# Create a count plot using Seaborn
sns.countplot(x='Category', data=df)

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Count')
plt.title('Count Plot of Categories')

# Show the plot
plt.show()

# %%
sns.countplot(label)
# Out:
# C:\Users\sahil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:ylabel='count'>

# %%
# Visualize 5 images for each class in the dataset

fig, axs = plt.subplots(5, 5, figsize = (20, 20))
count = 0
for i in os.listdir('./train'):
  # get the list of images in a given class
  train_class = os.listdir(os.path.join('train', i))
  # plot 5 images per class
  for j in range(5):
    img = os.path.join('train', i, train_class[j])
    img = PIL.Image.open(img)
    axs[count][j].title.set_text(i)
    axs[count][j].imshow(img)  
  count += 1

fig.tight_layout()

# %%
# check the number of images in each class in the training dataset

No_images_per_class = []
Class_name = []
for i in os.listdir('./train'):
  train_class = os.listdir(os.path.join('train', i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in Mild = 370
#
# Number of images in Moderate = 999
#
# Number of images in No_DR = 1805
#
# Number of images in Proliferate_DR = 295
#
# Number of images in Severe = 193

# %%
retina_df = pd.DataFrame({'Image': train,'Labels': label})
retina_df
# Out:
#                               Image  Labels
# 0       train\Mild\0024cdab0c1e.png    Mild
# 1       train\Mild\00cb6555d108.png    Mild
# 2       train\Mild\0124dffecf29.png    Mild
# 3       train\Mild\01b3aed3ed4c.png    Mild
# 4       train\Mild\0369f3efe69b.png    Mild
# ...                             ...     ...
# 3657  train\Severe\f9156aeffc5e.png  Severe
# 3658  train\Severe\fb61230b99dd.png  Severe
# 3659  train\Severe\fcc6aa6755e6.png  Severe
# 3660  train\Severe\fda39982a810.png  Severe
# 3661  train\Severe\fe0fc67c7980.png  Severe
#
# [3662 rows x 2 columns]

# %%
train
# Out:
# ['train\\Mild\\0024cdab0c1e.png',
#  'train\\Mild\\00cb6555d108.png',
#  'train\\Mild\\0124dffecf29.png',
#  'train\\Mild\\01b3aed3ed4c.png',
#  'train\\Mild\\0369f3efe69b.png',
#  'train\\Mild\\03e25101e8e8.png',
#  'train\\Mild\\04ac765f91a1.png',
#  'train\\Mild\\059bc89df7f4.png',
#  'train\\Mild\\05a5183c92d0.png',
#  'train\\Mild\\0684311afdfc.png',
#  'train\\Mild\\06b71823f9cd.png',
#  'train\\Mild\\07929d32b5b3.png',
#  'train\\Mild\\07a1c7073982.png',
#  'train\\Mild\\086d41d17da8.png',
#  'train\\Mild\\09935d72892b.png',
#  'train\\Mild\\0a3202889f4d.png',
#  'train\\Mild\\0a61bddab956.png',
#  'train\\Mild\\0ad7f631dedb.png',
#  'train\\Mild\\0d310aba6373.png',
#  'train\\Mild\\0dc031c94225.png',
#  'train\\Mild\\0dce95217626.png',
#  'train\\Mild\\0eb52045349f.png',
#  'train\\Mild\\0f495d87656a.png',
#  'train\\Mild\\0fb1053285cf.png',
#  'train\\Mild\\101b9ebfc720.png',
#  'train\\Mild\\107aea0d9289.png',
#  'train\\Mild\\10f36b0239fb.png',
#  'train\\Mild\\1116271db4ea.png',
#  'train\\Mild\\111898ab463d.png',
#  'train\\Mild\\12ce6a1a1f31.png',
#  'train\\Mild\\12e3f5f2cb17.png',
#  'train\\Mild\\13ab8db8c700.png',
#  'train\\Mild\\15cc2aef772a.png',
#  'train\\Mild\\172df1330a60.png',
#  'train\\Mild\\17eff993386f.png',
#  'train\\Mild\\18b06f56ab27.png',
#  'train\\Mild\\194814669fee.png',
#  'train\\Mild\\19722bff5a09.png',
#  'train\\Mild\\19e350c7c83c.png',
#  'train\\Mild\\1a03a7970337.png',
#  'train\\Mild\\1b329a127307.png',
#  'train\\Mild\\1bb0ddfe753a.png',
#  'train\\Mild\\1c0cf251b426.png',
#  'train\\Mild\\1c3a6b4449e9.png',
#  'train\\Mild\\1d11794057ff.png',
#  'train\\Mild\\1d674e2e32e0.png',
#  'train\\Mild\\1df3e03a8f5f.png',
#  'train\\Mild\\1e8a1fdee5b9.png',
#  'train\\Mild\\200d947f75db.png',
#  'train\\Mild\\22098b1fe461.png',
#  'train\\Mild\\22325552a4e3.png',
#  'train\\Mild\\22a6da005395.png',
#  'train\\Mild\\248139c423c4.png',
#  'train\\Mild\\24b943fe725e.png',
#  'train\\Mild\\259d30f693b6.png',
#  'train\\Mild\\25e9fd872182.png',
#  'train\\Mild\\274f5029189b.png',
#  'train\\Mild\\278aa860dffd.png',
#  'train\\Mild\\27e4c800a449.png',
#  'train\\Mild\\28f98cfe3858.png',
#  'train\\Mild\\2994f17f58a5.png',
#  'train\\Mild\\29b52f64d2db.png',
#  'train\\Mild\\2a08ed6bbcbc.png',
#  'train\\Mild\\2a8a9e957a6c.png',
#  'train\\Mild\\2d7666b8884f.png',
#  'train\\Mild\\2d9d97a6e713.png',
#  'train\\Mild\\2ecbc2e3f239.png',
#  'train\\Mild\\2f2e1949ad56.png',
#  'train\\Mild\\2f4e81787d9b.png',
#  'train\\Mild\\3044022c6969.png',
#  'train\\Mild\\30941b65348b.png',
#  'train\\Mild\\30cab14951ac.png',
#  'train\\Mild\\31cb39681f6a.png',
#  'train\\Mild\\33105f9b3a04.png',
#  'train\\Mild\\33b893e18eb3.png',
#  'train\\Mild\\33ffddea8c6e.png',
#  'train\\Mild\\3461dc601cc2.png',
#  'train\\Mild\\358d2224de73.png',
#  'train\\Mild\\35aa7f5c2ec0.png',
#  'train\\Mild\\35d6c4c50072.png',
#  'train\\Mild\\36041171f441.png',
#  'train\\Mild\\365f8c01d994.png',
#  'train\\Mild\\36677b70b1ef.png',
#  'train\\Mild\\382752f6694a.png',
#  'train\\Mild\\384631079d1e.png',
#  'train\\Mild\\38b9bb961847.png',
#  'train\\Mild\\38e0e28d35d3.png',
#  'train\\Mild\\3b73a3a4a734.png',
#  'train\\Mild\\3c726de3ee90.png',
#  'train\\Mild\\3c72f580d4ba.png',
#  'train\\Mild\\3dbc90c7ee7d.png',
#  'train\\Mild\\3de8ad4151e1.png',
#  'train\\Mild\\3ee17aa12e46.png',
#  'train\\Mild\\3f73c91b7e32.png',
#  'train\\Mild\\4029d70e9d8a.png',
#  'train\\Mild\\40e9b5630438.png',
#  'train\\Mild\\4393c5bc576a.png',
#  'train\\Mild\\45e4b7eada54.png',
#  'train\\Mild\\4661006f3ba6.png',
#  'train\\Mild\\47d1603a555b.png',
#  'train\\Mild\\49386d603494.png',
#  'train\\Mild\\494fc9c745a3.png',
#  'train\\Mild\\495255c7492f.png',
#  'train\\Mild\\49c5e7f6b8d2.png',
#  'train\\Mild\\4a213b405ee4.png',
#  'train\\Mild\\4aa07d720638.png',
#  'train\\Mild\\4c129470cec4.png',
#  'train\\Mild\\4c3c1ed09771.png',
#  'train\\Mild\\4cae247d9909.png',
#  'train\\Mild\\4d7d6928534a.png',
#  'train\\Mild\\4da2961e62fe.png',
#  'train\\Mild\\4dd5d5ccddcf.png',
#  'train\\Mild\\4dd9d29eae5d.png',
#  'train\\Mild\\4e0656629d02.png',
#  'train\\Mild\\4e6071b73120.png',
#  'train\\Mild\\4e82c3c8d31f.png',
#  'train\\Mild\\4ecd1fdd1435.png',
#  'train\\Mild\\4ef7144e24ff.png',
#  'train\\Mild\\4f7755e74a9e.png',
#  'train\\Mild\\4fa26d065ad3.png',
#  'train\\Mild\\50840c36f0b4.png',
#  'train\\Mild\\5090917a2676.png',
#  'train\\Mild\\51131b48f9d4.png',
#  'train\\Mild\\513b0a4651fa.png',
#  'train\\Mild\\523b3f0fc646.png',
#  'train\\Mild\\52ae917fcea4.png',
#  'train\\Mild\\531b39880c32.png',
#  'train\\Mild\\5347b4c8e9b3.png',
#  'train\\Mild\\53704c80f0d8.png',
#  'train\\Mild\\53f6c1c65c04.png',
#  'train\\Mild\\545df1bbcd61.png',
#  'train\\Mild\\5548a7961a3e.png',
#  'train\\Mild\\55eac26bd383.png',
#  'train\\Mild\\5633ced07d8e.png',
#  'train\\Mild\\5671eb95512b.png',
#  'train\\Mild\\5712e2aa73a2.png',
#  'train\\Mild\\5777ef74c9ec.png',
#  'train\\Mild\\578109578b46.png',
#  'train\\Mild\\58184d6fd087.png',
#  'train\\Mild\\582115961a3d.png',
#  'train\\Mild\\587146a55885.png',
#  'train\\Mild\\5879285f9d8d.png',
#  'train\\Mild\\58ccba7eec9c.png',
#  'train\\Mild\\595446774178.png',
#  'train\\Mild\\59e5212f7139.png',
#  'train\\Mild\\5a091e8cd95c.png',
#  'train\\Mild\\5b068765e846.png',
#  'train\\Mild\\5b0e53f53ef3.png',
#  'train\\Mild\\5b72ff04333d.png',
#  'train\\Mild\\5b804948e35f.png',
#  'train\\Mild\\5cab3ef4b31c.png',
#  'train\\Mild\\5efa24b03d5e.png',
#  'train\\Mild\\6028a575dc27.png',
#  'train\\Mild\\613bacb35c05.png',
#  'train\\Mild\\6165081b9021.png',
#  'train\\Mild\\61bbe8db6f3a.png',
#  'train\\Mild\\6298468d7d75.png',
#  'train\\Mild\\63363410389a.png',
#  'train\\Mild\\6377e23928f6.png',
#  'train\\Mild\\63a03880939c.png',
#  'train\\Mild\\64678182d8a8.png',
#  'train\\Mild\\64eb5a79dfdd.png',
#  'train\\Mild\\655cafb4c932.png',
#  'train\\Mild\\65e51e18242b.png',
#  'train\\Mild\\665ce639a331.png',
#  'train\\Mild\\66cd9c28e636.png',
#  'train\\Mild\\6762b2b48ea5.png',
#  'train\\Mild\\677f087cd697.png',
#  'train\\Mild\\67f5d89da548.png',
#  'train\\Mild\\68332fdcaa70.png',
#  'train\\Mild\\6b00cb764237.png',
#  'train\\Mild\\6b07971c3bf6.png',
#  'train\\Mild\\6c6efb6b1358.png',
#  'train\\Mild\\6cdd0f985270.png',
#  'train\\Mild\\6d292ca4c9ad.png',
#  'train\\Mild\\6ea07d19b4ce.png',
#  'train\\Mild\\7005be54cab1.png',
#  'train\\Mild\\7116128c65ab.png',
#  'train\\Mild\\71c1a3cdbe47.png',
#  'train\\Mild\\71f6a6e4620a.png',
#  'train\\Mild\\7335a2d43ada.png',
#  'train\\Mild\\7347f5133a6a.png',
#  'train\\Mild\\73881f55a3ec.png',
#  'train\\Mild\\7427dedafccf.png',
#  'train\\Mild\\756b0d6488bb.png',
#  'train\\Mild\\76be29bb30b2.png',
#  'train\\Mild\\76e589911303.png',
#  'train\\Mild\\77a9538b8362.png',
#  'train\\Mild\\78bcdffb8785.png',
#  'train\\Mild\\79ce83c07588.png',
#  'train\\Mild\\7a3ea1779b13.png',
#  'train\\Mild\\7ae69d22075a.png',
#  'train\\Mild\\7b20210d9120.png',
#  'train\\Mild\\7bf981d9c7fe.png',
#  'train\\Mild\\7ccb267fd394.png',
#  'train\\Mild\\7ea756985353.png',
#  'train\\Mild\\7ef5ff774a48.png',
#  'train\\Mild\\7f60f2a083d3.png',
#  'train\\Mild\\80a02014b418.png',
#  'train\\Mild\\80d24897669f.png',
#  'train\\Mild\\8114d6a160df.png',
#  'train\\Mild\\821789e9053f.png',
#  'train\\Mild\\8273fdb4405e.png',
#  'train\\Mild\\82ac8463fadd.png',
#  'train\\Mild\\83e529e95b0e.png',
#  'train\\Mild\\849a91e9ab28.png',
#  'train\\Mild\\84a72e15b23c.png',
#  'train\\Mild\\8676427e4625.png',
#  'train\\Mild\\8714d17bb6da.png',
#  'train\\Mild\\89d9c071a56f.png',
#  'train\\Mild\\89ed6a0dd53f.png',
#  'train\\Mild\\8a01daa423f7.png',
#  'train\\Mild\\8a25a080f28f.png',
#  'train\\Mild\\8bbd7835e9aa.png',
#  'train\\Mild\\8bc6716c2238.png',
#  'train\\Mild\\8c2f0f04e1ed.png',
#  'train\\Mild\\8dc22e65c06f.png',
#  'train\\Mild\\8ef2eb8c51c4.png',
#  'train\\Mild\\8f2996b8d855.png',
#  'train\\Mild\\8fc09fecd22f.png',
#  'train\\Mild\\8ff863f8874f.png',
#  'train\\Mild\\90c982cc2d96.png',
#  'train\\Mild\\92d9e9f08709.png',
#  'train\\Mild\\93be637084a2.png',
#  'train\\Mild\\94111ed3d276.png',
#  'train\\Mild\\94372043d55b.png',
#  'train\\Mild\\944a233fbf8e.png',
#  'train\\Mild\\94b1d8ad35ec.png',
#  'train\\Mild\\95a4cc805c7b.png',
#  'train\\Mild\\96a9706b8534.png',
#  'train\\Mild\\977e1ca77653.png',
#  'train\\Mild\\9782c0489eca.png',
#  'train\\Mild\\98fbe56dcc2c.png',
#  'train\\Mild\\99132193eaa0.png',
#  'train\\Mild\\99ecdb41d5e7.png',
#  'train\\Mild\\9a3109657ac1.png',
#  'train\\Mild\\9eaf735cf01f.png',
#  'train\\Mild\\9ed666e982cd.png',
#  'train\\Mild\\a00b4cb250a7.png',
#  'train\\Mild\\a01024054596.png',
#  'train\\Mild\\a19ecd0a706e.png',
#  'train\\Mild\\a2696f444ecb.png',
#  'train\\Mild\\a28bfb772f50.png',
#  'train\\Mild\\a32886cb31ab.png',
#  'train\\Mild\\a3ad6c2db6f1.png',
#  'train\\Mild\\a3d2a0c4cd17.png',
#  'train\\Mild\\a443c4fd489c.png',
#  'train\\Mild\\a47432cd41e7.png',
#  'train\\Mild\\a5a2a7003d60.png',
#  'train\\Mild\\a75bab2463d4.png',
#  'train\\Mild\\a77dbec966d4.png',
#  'train\\Mild\\a7ec056502e7.png',
#  'train\\Mild\\a8582e346df0.png',
#  'train\\Mild\\a8c54e2a4b79.png',
#  'train\\Mild\\a8c950a99107.png',
#  'train\\Mild\\a95858e052d6.png',
#  'train\\Mild\\ababe19ed448.png',
#  'train\\Mild\\abdb365cacbc.png',
#  'train\\Mild\\ad1f7445b1a8.png',
#  'train\\Mild\\ad3fc5076852.png',
#  'train\\Mild\\ae8472f8d310.png',
#  'train\\Mild\\af133a85ea0c.png',
#  'train\\Mild\\b07bc463b718.png',
#  'train\\Mild\\b1197f2cc9b3.png',
#  'train\\Mild\\b17f0b81dab3.png',
#  'train\\Mild\\b22354b5f94b.png',
#  'train\\Mild\\b4f41b5bf0ef.png',
#  'train\\Mild\\b50b30aa6e6c.png',
#  'train\\Mild\\b56340f472d2.png',
#  'train\\Mild\\b576c5269ad1.png',
#  'train\\Mild\\b640e3bdff75.png',
#  'train\\Mild\\b6a0e348a01e.png',
#  'train\\Mild\\b71428739d4e.png',
#  'train\\Mild\\b7278b4f2448.png',
#  'train\\Mild\\b8ebedd382de.png',
#  'train\\Mild\\b94c58d063bf.png',
#  'train\\Mild\\b9b99dad668d.png',
#  'train\\Mild\\bacfb1029f6b.png',
#  'train\\Mild\\bb11db08584a.png',
#  'train\\Mild\\bb45257258cc.png',
#  'train\\Mild\\bb783d8e496f.png',
#  'train\\Mild\\bb9a3d835a94.png',
#  'train\\Mild\\bc73ce76ec43.png',
#  'train\\Mild\\bd269a1f0e4d.png',
#  'train\\Mild\\bebb3f167654.png',
#  'train\\Mild\\bf18ff30a8f6.png',
#  'train\\Mild\\c027e5482e8c.png',
#  'train\\Mild\\c0968d41eb93.png',
#  'train\\Mild\\c0e15e8e2b46.png',
#  'train\\Mild\\c0f15fe3b4b7.png',
#  'train\\Mild\\c102db7634d8.png',
#  'train\\Mild\\c1e6fa1ad314.png',
#  'train\\Mild\\c1ebe785503a.png',
#  'train\\Mild\\c40976189f22.png',
#  'train\\Mild\\c4a8f2fcf6e8.png',
#  'train\\Mild\\c56e65f74187.png',
#  'train\\Mild\\c739ff9580d3.png',
#  'train\\Mild\\c7b622ec8104.png',
#  'train\\Mild\\c8fc0df22999.png',
#  'train\\Mild\\c9485c38fdd5.png',
#  'train\\Mild\\c96f743915b5.png',
#  'train\\Mild\\ca1036496659.png',
#  'train\\Mild\\ca25745942b0.png',
#  'train\\Mild\\ca30a97e9d13.png',
#  'train\\Mild\\ca63fe4f4b52.png',
#  'train\\Mild\\ca6842bfcbc9.png',
#  'train\\Mild\\ca7140ecf389.png',
#  'train\\Mild\\cab3dfa7962d.png',
#  'train\\Mild\\cae51154e1ce.png',
#  'train\\Mild\\cb2f3c5d71a7.png',
#  'train\\Mild\\cc12453ea915.png',
#  'train\\Mild\\cc9270f06b65.png',
#  'train\\Mild\\cd45bfa07d41.png',
#  'train\\Mild\\cd5714db652d.png',
#  'train\\Mild\\cf0575534cec.png',
#  'train\\Mild\\cf603a9ef2d5.png',
#  'train\\Mild\\cfd1bd0fcbb4.png',
#  'train\\Mild\\d06ccd0cf4b8.png',
#  'train\\Mild\\d0d59ed675b5.png',
#  'train\\Mild\\d1cad012a254.png',
#  'train\\Mild\\d3de0d313d61.png',
#  'train\\Mild\\d4f32b9c07df.png',
#  'train\\Mild\\d567a1a22d33.png',
#  'train\\Mild\\d5b4705ac2ee.png',
#  'train\\Mild\\d66b6f333dc7.png',
#  'train\\Mild\\d66ccb75ada1.png',
#  'train\\Mild\\d6e26fe51dce.png',
#  'train\\Mild\\d801c0a66738.png',
#  'train\\Mild\\d85588ff2ebd.png',
#  'train\\Mild\\d85d052900b4.png',
#  'train\\Mild\\da1fb35f5df9.png',
#  'train\\Mild\\db4ed1e07aa3.png',
#  'train\\Mild\\db690e2d02f8.png',
#  'train\\Mild\\dbd062558b81.png',
#  'train\\Mild\\dd19428c3d29.png',
#  'train\\Mild\\e07045d7c5f7.png',
#  'train\\Mild\\e25ccfe38e44.png',
#  'train\\Mild\\e26d8718ca58.png',
#  'train\\Mild\\e2a233493b90.png',
#  'train\\Mild\\e38f3a65b02b.png',
#  'train\\Mild\\e55188915f9d.png',
#  'train\\Mild\\e580676516b0.png',
#  'train\\Mild\\e9286ddf6ffe.png',
#  'train\\Mild\\e96bd80a8a53.png',
#  'train\\Mild\\e9ff9352ccb3.png',
#  'train\\Mild\\ea15a290eb96.png',
#  'train\\Mild\\ead23cc922ed.png',
#  'train\\Mild\\eba3acc42197.png',
#  'train\\Mild\\ec4649213ccf.png',
#  'train\\Mild\\ee78ce914066.png',
#  'train\\Mild\\eeb231c3ef1f.png',
#  'train\\Mild\\eed4afc8ec83.png',
#  'train\\Mild\\ef8109305128.png',
#  'train\\Mild\\f0c13be90519.png',
#  'train\\Mild\\f47a2a4a0411.png',
#  'train\\Mild\\f481f76a6b75.png',
#  'train\\Mild\\f55e1d2a19e4.png',
#  'train\\Mild\\f5650eb52640.png',
#  'train\\Mild\\f6f7dba7104d.png',
#  'train\\Mild\\f72ef9ceeaa8.png',
#  'train\\Mild\\f762c272c522.png',
#  'train\\Mild\\f7fec8935126.png',
#  'train\\Mild\\fb6b8200b7f8.png',
#  'train\\Mild\\fca931da5c5e.png',
#  'train\\Mild\\fd62bd0db4f1.png',
#  'train\\Mild\\fdd18ccbbdc5.png',
#  'train\\Mild\\fe2df69676cf.png',
#  'train\\Mild\\fe674c2f73f5.png',
#  'train\\Mild\\fea14b3d44b0.png',
#  'train\\Mild\\fecf4c5ae84b.png',
#  'train\\Moderate\\000c1434d8d7.png',
#  'train\\Moderate\\00a8624548a9.png',
#  'train\\Moderate\\00b74780d31d.png',
#  'train\\Moderate\\00e4ddff966a.png',
#  'train\\Moderate\\012a242ac6ff.png',
#  'train\\Moderate\\0161338f53cc.png',
#  'train\\Moderate\\0180bfa26c0b.png',
#  'train\\Moderate\\01c7808d901d.png',
#  'train\\Moderate\\01eb826f6467.png',
#  'train\\Moderate\\025a169a0bb0.png',
#  'train\\Moderate\\026dcd9af143.png',
#  'train\\Moderate\\032d7b0b4bf6.png',
#  'train\\Moderate\\033f2b43de6d.png',
#  'train\\Moderate\\03676c71ed1b.png',
#  'train\\Moderate\\03747397839f.png',
#  'train\\Moderate\\03fd50da928d.png',
#  'train\\Moderate\\03ff7d159f10.png',
#  'train\\Moderate\\0415fc68b176.png',
#  'train\\Moderate\\041f09eec1e8.png',
#  'train\\Moderate\\04a6fc58dabc.png',
#  'train\\Moderate\\04d029cfb612.png',
#  'train\\Moderate\\0519b934f6b1.png',
#  'train\\Moderate\\052d9a3fe55a.png',
#  'train\\Moderate\\06024377d573.png',
#  'train\\Moderate\\064af6592ba6.png',
#  'train\\Moderate\\07083738b75e.png',
#  'train\\Moderate\\071435a218ec.png',
#  'train\\Moderate\\07419eddd6be.png',
#  'train\\Moderate\\07a3be30563b.png',
#  'train\\Moderate\\07d8db76b301.png',
#  'train\\Moderate\\08752092140d.png',
#  'train\\Moderate\\08c17a2d95b7.png',
#  'train\\Moderate\\094858f005ab.png',
#  'train\\Moderate\\0953c0ac1735.png',
#  'train\\Moderate\\09eeafa9656a.png',
#  'train\\Moderate\\09f6ab477654.png',
#  'train\\Moderate\\0a09aa7356c0.png',
#  'train\\Moderate\\0a1076183736.png',
#  'train\\Moderate\\0a9ec1e99ce4.png',
#  'train\\Moderate\\0ac436400db4.png',
#  'train\\Moderate\\0af296d2f04a.png',
#  'train\\Moderate\\0afdfe5f422c.png',
#  'train\\Moderate\\0c2e2369dfff.png',
#  'train\\Moderate\\0c55d58bebaf.png',
#  'train\\Moderate\\0c76fd494af6.png',
#  'train\\Moderate\\0c7e82daf5a0.png',
#  'train\\Moderate\\0ca0aee4d57e.png',
#  'train\\Moderate\\0d0a21fd354f.png',
#  'train\\Moderate\\0da09e3ce8f1.png',
#  'train\\Moderate\\0dbaa09a458c.png',
#  'train\\Moderate\\0e75d51152fc.png',
#  'train\\Moderate\\0efc93ec838b.png',
#  'train\\Moderate\\0eff8eacb2f7.png',
#  'train\\Moderate\\0fb560f9adb2.png',
#  'train\\Moderate\\0fcfc6301f3d.png',
#  'train\\Moderate\\0fd16b64697e.png',
#  'train\\Moderate\\0fffa73e2402.png',
#  'train\\Moderate\\1006345f70b7.png',
#  'train\\Moderate\\10ecc5292ab1.png',
#  'train\\Moderate\\10eefba568dd.png',
#  'train\\Moderate\\1120f6d08d95.png',
#  'train\\Moderate\\1124ffcd76c2.png',
#  'train\\Moderate\\115e42dd6a81.png',
#  'train\\Moderate\\1177d583c807.png',
#  'train\\Moderate\\11b5c77fbf79.png',
#  'train\\Moderate\\12025b34deb8.png',
#  'train\\Moderate\\1269ab57c2e6.png',
#  'train\\Moderate\\12a82fc7d73e.png',
#  'train\\Moderate\\12e6e66c80a7.png',
#  'train\\Moderate\\13063d1bc4ea.png',
#  'train\\Moderate\\135575dc57c9.png',
#  'train\\Moderate\\13d71389563f.png',
#  'train\\Moderate\\1411c8ab7161.png',
#  'train\\Moderate\\1414128bead0.png',
#  'train\\Moderate\\141735b57ec0.png',
#  'train\\Moderate\\1438288bb2e1.png',
#  'train\\Moderate\\144a1a426137.png',
#  'train\\Moderate\\144b01e7b993.png',
#  'train\\Moderate\\14515b8f19b6.png',
#  'train\\Moderate\\14ee87d6cc42.png',
#  'train\\Moderate\\1541226c5d72.png',
#  'train\\Moderate\\15528e740543.png',
#  'train\\Moderate\\157d17349cc6.png',
#  'train\\Moderate\\1594ca6c30d3.png',
#  'train\\Moderate\\15cd5f52d300.png',
#  'train\\Moderate\\1632c4311fc9.png',
#  'train\\Moderate\\17188c13e635.png',
#  'train\\Moderate\\175dd560810a.png',
#  'train\\Moderate\\17eb5d4ad740.png',
#  'train\\Moderate\\180afe1d5ef7.png',
#  'train\\Moderate\\18323d8f2470.png',
#  'train\\Moderate\\1844a039b4ea.png',
#  'train\\Moderate\\188a9323be03.png',
#  'train\\Moderate\\18af532e7e1e.png',
#  'train\\Moderate\\18d8fdb140b7.png',
#  'train\\Moderate\\18f1f979d30d.png',
#  'train\\Moderate\\19113e5f45ec.png',
#  'train\\Moderate\\191348830ddf.png',
#  'train\\Moderate\\1943983492e5.png',
#  'train\\Moderate\\1968183f0e61.png',
#  'train\\Moderate\\196e6a186452.png',
#  'train\\Moderate\\1a1b4b2450ca.png',
#  'train\\Moderate\\1a369baf9ee6.png',
#  'train\\Moderate\\1ade1e949383.png',
#  'train\\Moderate\\1ae8c165fd53.png',
#  'train\\Moderate\\1b4625877527.png',
#  'train\\Moderate\\1b8ad0afe9fb.png',
#  'train\\Moderate\\1bea04b2bb2d.png',
#  'train\\Moderate\\1c0e5dd1b14c.png',
#  'train\\Moderate\\1c4d87baaffc.png',
#  'train\\Moderate\\1c578b72d7b3.png',
#  'train\\Moderate\\1c5ad36fb799.png',
#  'train\\Moderate\\1c5e6cdc7ee1.png',
#  'train\\Moderate\\1c6d119c3d70.png',
#  'train\\Moderate\\1cb814ed6332.png',
#  'train\\Moderate\\1d14dd912671.png',
#  'train\\Moderate\\1d55e689cf84.png',
#  'train\\Moderate\\1da25637859b.png',
#  'train\\Moderate\\1db18bdd43aa.png',
#  'train\\Moderate\\1dbdc32c17db.png',
#  'train\\Moderate\\1dd9adcbfff4.png',
#  'train\\Moderate\\1dfbede13143.png',
#  'train\\Moderate\\1e143fa3de57.png',
#  'train\\Moderate\\1e1fb019710d.png',
#  'train\\Moderate\\1e4650743fa2.png',
#  'train\\Moderate\\1e4b3b823b95.png',
#  'train\\Moderate\\1ee1eb7943db.png',
#  'train\\Moderate\\1f07dae3cadb.png',
#  'train\\Moderate\\1f0e223b8055.png',
#  'train\\Moderate\\1f4bf8e28b41.png',
#  'train\\Moderate\\1f543a86c4d4.png',
#  'train\\Moderate\\1f63d44d9e3c.png',
#  'train\\Moderate\\1ffaa51a6245.png',
#  'train\\Moderate\\203275daf46d.png',
#  'train\\Moderate\\20404ec7b518.png',
#  'train\\Moderate\\20688cb25704.png',
#  'train\\Moderate\\207a580de0ea.png',
#  'train\\Moderate\\20c883d3bd38.png',
#  'train\\Moderate\\2131aa3a1e6f.png',
#  'train\\Moderate\\217dad18a5ed.png',
#  'train\\Moderate\\222d0ac042b4.png',
#  'train\\Moderate\\2241b7e90782.png',
#  'train\\Moderate\\224bb938e2dd.png',
#  'train\\Moderate\\22ce8ef69357.png',
#  'train\\Moderate\\23148a40ecb0.png',
#  'train\\Moderate\\23175b7ef453.png',
#  'train\\Moderate\\232549883508.png',
#  'train\\Moderate\\234399352d36.png',
#  'train\\Moderate\\236f56771ec6.png',
#  'train\\Moderate\\2376e5415458.png',
#  'train\\Moderate\\239f2c348ea4.png',
#  'train\\Moderate\\23d7ca170bdb.png',
#  'train\\Moderate\\23fca0693e2a.png',
#  'train\\Moderate\\2463bb04ebc3.png',
#  'train\\Moderate\\246e4506824a.png',
#  'train\\Moderate\\25002fe43f92.png',
#  'train\\Moderate\\2532613a584a.png',
#  'train\\Moderate\\25dc1b41ed9c.png',
#  'train\\Moderate\\2608e1dac5b1.png',
#  'train\\Moderate\\261c6bd63bff.png',
#  'train\\Moderate\\26453eb7e989.png',
#  'train\\Moderate\\26999ebc21de.png',
#  'train\\Moderate\\269f0792f11f.png',
#  'train\\Moderate\\26e231747848.png',
#  'train\\Moderate\\2700754f71e9.png',
#  'train\\Moderate\\272d9c043c81.png',
#  'train\\Moderate\\2735be026d44.png',
#  'train\\Moderate\\2776d70724d3.png',
#  'train\\Moderate\\27b68863349f.png',
#  'train\\Moderate\\27bab1432f61.png',
#  'train\\Moderate\\27fca9f12b3c.png',
#  'train\\Moderate\\282bc792d23a.png',
#  'train\\Moderate\\28824d12d31d.png',
#  'train\\Moderate\\28a4d00927b7.png',
#  'train\\Moderate\\28f93cad89c5.png',
#  'train\\Moderate\\290ecdba359f.png',
#  'train\\Moderate\\291e2ff3d834.png',
#  'train\\Moderate\\29580bed2f7d.png',
#  'train\\Moderate\\295fdc964f6e.png',
#  'train\\Moderate\\2967e578939f.png',
#  'train\\Moderate\\29f44aea93a4.png',
#  'train\\Moderate\\2a099b247b10.png',
#  'train\\Moderate\\2a3378bcfbcc.png',
#  'train\\Moderate\\2a3a1ed1c285.png',
#  'train\\Moderate\\2a47e5b21791.png',
#  'train\\Moderate\\2a5a8b744f08.png',
#  'train\\Moderate\\2af1bf226f51.png',
#  'train\\Moderate\\2b074afdf626.png',
#  'train\\Moderate\\2b07790a2422.png',
#  'train\\Moderate\\2b21d293fdf2.png',
#  'train\\Moderate\\2b88cb6e31cd.png',
#  'train\\Moderate\\2ba0b0d9bda2.png',
#  'train\\Moderate\\2bd4d4fbed5c.png',
#  'train\\Moderate\\2c1d5be654dd.png',
#  'train\\Moderate\\2c2aa057afc5.png',
#  'train\\Moderate\\2cbfc6182ba2.png',
#  'train\\Moderate\\2cceb07ff706.png',
#  'train\\Moderate\\2cef97083e6f.png',
#  'train\\Moderate\\2d552318eb07.png',
#  'train\\Moderate\\2d870833c0c9.png',
#  'train\\Moderate\\2e26762daed5.png',
#  'train\\Moderate\\2e79041ef722.png',
#  'train\\Moderate\\2f5c9cdfb333.png',
#  'train\\Moderate\\2f9b66784109.png',
#  'train\\Moderate\\2fb3a8606a77.png',
#  'train\\Moderate\\2fdffb6160a6.png',
#  'train\\Moderate\\300305ce82d2.png',
#  'train\\Moderate\\302bcdb635ff.png',
#  'train\\Moderate\\308f7fce6f0d.png',
#  'train\\Moderate\\310c27067ac0.png',
#  'train\\Moderate\\3128eb593012.png',
#  'train\\Moderate\\31452ad8808c.png',
#  'train\\Moderate\\314862758acf.png',
#  'train\\Moderate\\31b5d6fb0256.png',
#  'train\\Moderate\\3246f07e65b4.png',
#  'train\\Moderate\\32a3eb37ff40.png',
#  'train\\Moderate\\331b87d1b9d1.png',
#  'train\\Moderate\\33e8e26a75d4.png',
#  'train\\Moderate\\3402124408ea.png',
#  'train\\Moderate\\3428230bf1bd.png',
#  'train\\Moderate\\34723fae6475.png',
#  'train\\Moderate\\349f3c0ac83e.png',
#  'train\\Moderate\\354b8911d6ed.png',
#  'train\\Moderate\\362c4a96cebb.png',
#  'train\\Moderate\\367c7049929c.png',
#  'train\\Moderate\\36a1e3c780a0.png',
#  'train\\Moderate\\36ec36c301c1.png',
#  'train\\Moderate\\3748349334f6.png',
#  'train\\Moderate\\37de05ef12a5.png',
#  'train\\Moderate\\38487e1a5b1f.png',
#  'train\\Moderate\\388f12e8df0b.png',
#  'train\\Moderate\\38e111cac46f.png',
#  'train\\Moderate\\38fe9f854046.png',
#  'train\\Moderate\\39134907127a.png',
#  'train\\Moderate\\39923b29988a.png',
#  'train\\Moderate\\39b5b05d6cd9.png',
#  'train\\Moderate\\3a122851e526.png',
#  'train\\Moderate\\3a1d3ce00f0c.png',
#  'train\\Moderate\\3a61e690f4bb.png',
#  'train\\Moderate\\3aa2b1ce6700.png',
#  'train\\Moderate\\3b58b02c89ed.png',
#  'train\\Moderate\\3b9c1f42c2f2.png',
#  'train\\Moderate\\3c1efa38d0da.png',
#  'train\\Moderate\\3c311c9109b0.png',
#  'train\\Moderate\\3c53198519f7.png',
#  'train\\Moderate\\3cd801ffdbf0.png',
#  'train\\Moderate\\3cdda8b3df19.png',
#  'train\\Moderate\\3d3e288d490e.png',
#  'train\\Moderate\\3d663a6a50a3.png',
#  'train\\Moderate\\3dbfbc11e105.png',
#  'train\\Moderate\\3ddb86eb530e.png',
#  'train\\Moderate\\3dfc50108072.png',
#  'train\\Moderate\\3e1f8fecb06f.png',
#  'train\\Moderate\\3e6bfc4d5c65.png',
#  'train\\Moderate\\3e86335bc2fd.png',
#  'train\\Moderate\\3f3de2a6b0f5.png',
#  'train\\Moderate\\3f47f83217b5.png',
#  'train\\Moderate\\3f5b4c2948e8.png',
#  'train\\Moderate\\3f8d5c940ba4.png',
#  'train\\Moderate\\3fc219927a97.png',
#  'train\\Moderate\\3fd7df6099e3.png',
#  'train\\Moderate\\3ffa14d60b24.png',
#  'train\\Moderate\\40140a925c43.png',
#  'train\\Moderate\\40527a5e95dd.png',
#  'train\\Moderate\\417f408ee8e0.png',
#  'train\\Moderate\\4189d4e631ec.png',
#  'train\\Moderate\\419406328dcd.png',
#  'train\\Moderate\\423abbaa5fad.png',
#  'train\\Moderate\\4242c0d87f57.png',
#  'train\\Moderate\\4246ed634f25.png',
#  'train\\Moderate\\4289af3afbd2.png',
#  'train\\Moderate\\42a67337fa8e.png',
#  'train\\Moderate\\42a850acd2ac.png',
#  'train\\Moderate\\42b08dca9b2f.png',
#  'train\\Moderate\\42b93b574f23.png',
#  'train\\Moderate\\435d900fa7b2.png',
#  'train\\Moderate\\436e1793d240.png',
#  'train\\Moderate\\437900a99871.png',
#  'train\\Moderate\\437cbec4a3f8.png',
#  'train\\Moderate\\4384fa687afa.png',
#  'train\\Moderate\\43ddd0ab0cc4.png',
#  'train\\Moderate\\43fb6eda9b97.png',
#  'train\\Moderate\\441117562359.png',
#  'train\\Moderate\\441affbe99aa.png',
#  'train\\Moderate\\4478b870e549.png',
#  'train\\Moderate\\44855f666225.png',
#  'train\\Moderate\\4489d421e5aa.png',
#  'train\\Moderate\\44c869174e3a.png',
#  'train\\Moderate\\44e0d56e9d42.png',
#  'train\\Moderate\\44e951e45dca.png',
#  'train\\Moderate\\44f4ae58990e.png',
#  'train\\Moderate\\453a1e2754b2.png',
#  'train\\Moderate\\453d553b0a94.png',
#  'train\\Moderate\\45ae04cfde5d.png',
#  'train\\Moderate\\45c39ab9e797.png',
#  'train\\Moderate\\460893cd86e3.png',
#  'train\\Moderate\\465c618f7b23.png',
#  'train\\Moderate\\467b7d9d811c.png',
#  'train\\Moderate\\46923eea9a4e.png',
#  'train\\Moderate\\46c1548d730e.png',
#  'train\\Moderate\\46f56c38051f.png',
#  'train\\Moderate\\475c7ded0f7a.png',
#  'train\\Moderate\\47b756014447.png',
#  'train\\Moderate\\47e51065b819.png',
#  'train\\Moderate\\4818672273af.png',
#  'train\\Moderate\\48543037d0b3.png',
#  'train\\Moderate\\48afe8c47454.png',
#  'train\\Moderate\\48c49f662f7d.png',
#  'train\\Moderate\\48c72dec46e5.png',
#  'train\\Moderate\\48fda42bd5d4.png',
#  'train\\Moderate\\49419f8d5cb4.png',
#  'train\\Moderate\\49a4765f8822.png',
#  'train\\Moderate\\49d69c4c6290.png',
#  'train\\Moderate\\4a0890b08532.png',
#  'train\\Moderate\\4a0bba3b7d83.png',
#  'train\\Moderate\\4a44cc840ebe.png',
#  'train\\Moderate\\4a558a1cd243.png',
#  'train\\Moderate\\4ad6109706e8.png',
#  'train\\Moderate\\4b1001050f1d.png',
#  'train\\Moderate\\4b422b48d0d4.png',
#  'train\\Moderate\\4b5ffea77373.png',
#  'train\\Moderate\\4c52922f3bfd.png',
#  'train\\Moderate\\4c78d9d18da9.png',
#  'train\\Moderate\\4ce74e5eb51d.png',
#  'train\\Moderate\\4d009cebabc9.png',
#  'train\\Moderate\\4d1cf360b2d7.png',
#  'train\\Moderate\\4d21ce39c905.png',
#  'train\\Moderate\\4da6e2089d57.png',
#  'train\\Moderate\\4dbce359d0e1.png',
#  'train\\Moderate\\4e43d05cc2ef.png',
#  'train\\Moderate\\4e7694eebb91.png',
#  'train\\Moderate\\4ed31cc07366.png',
#  'train\\Moderate\\4ee1ad981a6d.png',
#  'train\\Moderate\\4ef0b485a7da.png',
#  'train\\Moderate\\4f20f9a9a65b.png',
#  'train\\Moderate\\4f46d7ee61ed.png',
#  'train\\Moderate\\4f60129e9a5b.png',
#  'train\\Moderate\\50d8a8fb7737.png',
#  'train\\Moderate\\51030843fde2.png',
#  'train\\Moderate\\510aa0a898fa.png',
#  'train\\Moderate\\51405d042000.png',
#  'train\\Moderate\\5152bf091152.png',
#  'train\\Moderate\\5173d54fc214.png',
#  'train\\Moderate\\5188a8afa879.png',
#  'train\\Moderate\\51cfeccaf40d.png',
#  'train\\Moderate\\51d0034d177d.png',
#  'train\\Moderate\\51d574513bcb.png',
#  'train\\Moderate\\51d780864365.png',
#  'train\\Moderate\\521d3e264d71.png',
#  'train\\Moderate\\52230bbef30e.png',
#  'train\\Moderate\\523d0c2cb4d6.png',
#  'train\\Moderate\\523ff163211b.png',
#  'train\\Moderate\\524f240e0c90.png',
#  'train\\Moderate\\525acfea47e8.png',
#  'train\\Moderate\\5265dc9acdf8.png',
#  'train\\Moderate\\527bea76116c.png',
#  'train\\Moderate\\52886bed8a07.png',
#  'train\\Moderate\\52dbec057cc8.png',
#  'train\\Moderate\\530d78467615.png',
#  'train\\Moderate\\5327f88a1919.png',
#  'train\\Moderate\\541db13517e2.png',
#  'train\\Moderate\\547b37da9223.png',
#  'train\\Moderate\\5486da4273d7.png',
#  'train\\Moderate\\54bbe3da103e.png',
#  'train\\Moderate\\54cab3596214.png',
#  'train\\Moderate\\54dc6e8107cd.png',
#  'train\\Moderate\\55034b1dbff2.png',
#  'train\\Moderate\\55092c0071eb.png',
#  'train\\Moderate\\55fd453001cc.png',
#  'train\\Moderate\\56e56aa08362.png',
#  'train\\Moderate\\5723d0ec895e.png',
#  'train\\Moderate\\57469423a012.png',
#  'train\\Moderate\\57760be09c03.png',
#  'train\\Moderate\\57a5f1015504.png',
#  'train\\Moderate\\57ce57a8cfb0.png',
#  'train\\Moderate\\57f933d3d7c7.png',
#  'train\\Moderate\\582f739b8f62.png',
#  'train\\Moderate\\58529a8638d0.png',
#  'train\\Moderate\\5905a9b06a73.png',
#  'train\\Moderate\\594f69b503ad.png',
#  'train\\Moderate\\599b89048034.png',
#  'train\\Moderate\\59ee65760535.png',
#  'train\\Moderate\\59f3f70abddd.png',
#  'train\\Moderate\\5a03fe3ed15c.png',
#  'train\\Moderate\\5a11d21c2828.png',
#  'train\\Moderate\\5a2c27b95c7c.png',
#  'train\\Moderate\\5a36cea278ae.png',
#  'train\\Moderate\\5a5d3798c357.png',
#  'train\\Moderate\\5b301a6d1ac7.png',
#  'train\\Moderate\\5b644a403e1f.png',
#  'train\\Moderate\\5c6194562ed2.png',
#  'train\\Moderate\\5c8482926a08.png',
#  'train\\Moderate\\5cc6dea19614.png',
#  'train\\Moderate\\5cde55f745af.png',
#  'train\\Moderate\\5cf9127f251a.png',
#  'train\\Moderate\\5d024177e214.png',
#  'train\\Moderate\\5dc23e440de3.png',
#  'train\\Moderate\\5e18af29d812.png',
#  'train\\Moderate\\5e52c9fe676f.png',
#  'train\\Moderate\\5e7630f8438e.png',
#  'train\\Moderate\\5e7cc6ab4ac4.png',
#  'train\\Moderate\\5eb311bcb5f9.png',
#  'train\\Moderate\\5ed6dc419e4d.png',
#  'train\\Moderate\\5f70ad48a525.png',
#  'train\\Moderate\\60e269e3e188.png',
#  'train\\Moderate\\60eeae3ba23d.png',
#  'train\\Moderate\\61ac9b0dc6b9.png',
#  'train\\Moderate\\61c2fbd16e38.png',
#  'train\\Moderate\\624fb7317106.png',
#  'train\\Moderate\\62ab144d5cee.png',
#  'train\\Moderate\\62cc7ddb53b6.png',
#  'train\\Moderate\\62e6f814c8f5.png',
#  'train\\Moderate\\62ecdc90dd42.png',
#  'train\\Moderate\\6363b360aefb.png',
#  'train\\Moderate\\63c3c571b8ee.png',
#  'train\\Moderate\\63d217b059b6.png',
#  'train\\Moderate\\64a13949e879.png',
#  'train\\Moderate\\650fbed3fdca.png',
#  'train\\Moderate\\6531070bf03c.png',
#  'train\\Moderate\\653534ded339.png',
#  'train\\Moderate\\657859f893d9.png',
#  'train\\Moderate\\65e530ee2e79.png',
#  'train\\Moderate\\663a923d5398.png',
#  'train\\Moderate\\6666c4f18396.png',
#  'train\\Moderate\\668e853258cd.png',
#  'train\\Moderate\\66bae1ba227f.png',
#  'train\\Moderate\\66d2ca47aa44.png',
#  'train\\Moderate\\6733544ae7a6.png',
#  'train\\Moderate\\674057ab250c.png',
#  'train\\Moderate\\67844c46bc61.png',
#  'train\\Moderate\\67c03349bb31.png',
#  'train\\Moderate\\6810410187a0.png',
#  'train\\Moderate\\681c3c115684.png',
#  'train\\Moderate\\686ed1dbae20.png',
#  'train\\Moderate\\6889bc64ab09.png',
#  'train\\Moderate\\69591ebb198d.png',
#  'train\\Moderate\\6987804eb464.png',
#  'train\\Moderate\\698d6e422a80.png',
#  'train\\Moderate\\69df7ade0575.png',
#  'train\\Moderate\\6a91eb157f47.png',
#  'train\\Moderate\\6b7cf869622a.png',
#  'train\\Moderate\\6b869f37cdf3.png',
#  'train\\Moderate\\6ba5ed791444.png',
#  'train\\Moderate\\6c2555a9cae4.png',
#  'train\\Moderate\\6c315ad3d07f.png',
#  'train\\Moderate\\6cb98da77e3e.png',
#  'train\\Moderate\\6cbc3dad809c.png',
#  'train\\Moderate\\6d3d1fe6c32a.png',
#  'train\\Moderate\\6d454444f17c.png',
#  'train\\Moderate\\6dcde47060f9.png',
#  'train\\Moderate\\6dfd80748e72.png',
#  'train\\Moderate\\6e092b306fe1.png',
#  'train\\Moderate\\6e68e742f5bc.png',
#  'train\\Moderate\\6f0463c1ff18.png',
#  'train\\Moderate\\6f4e0538d1e4.png',
#  'train\\Moderate\\709784f7fcc2.png',
#  'train\\Moderate\\70ed3ec68b94.png',
#  'train\\Moderate\\70f5caf5f305.png',
#  'train\\Moderate\\7102f29e052e.png',
#  'train\\Moderate\\711d1480d2e3.png',
#  'train\\Moderate\\71e4130bf5c8.png',
#  'train\\Moderate\\7247a2c97f71.png',
#  'train\\Moderate\\731b19a460ad.png',
#  'train\\Moderate\\7350c50667c5.png',
#  'train\\Moderate\\7356dd08b0ae.png',
#  'train\\Moderate\\73e83a07a16d.png',
#  'train\\Moderate\\74418f620068.png',
#  'train\\Moderate\\7455e2b5fc57.png',
#  'train\\Moderate\\7550966ef777.png',
#  'train\\Moderate\\757572337fd0.png',
#  'train\\Moderate\\75a7bc945b7d.png',
#  'train\\Moderate\\760b6f4c6d82.png',
#  'train\\Moderate\\7663aba8d762.png',
#  'train\\Moderate\\76c0c7e1b6cb.png',
#  'train\\Moderate\\76cfe8967f7d.png',
#  'train\\Moderate\\76e6a9238570.png',
#  'train\\Moderate\\76fe19ff64fb.png',
#  'train\\Moderate\\7743f4e04a6d.png',
#  'train\\Moderate\\77543f66a84a.png',
#  'train\\Moderate\\77baa08a1345.png',
#  'train\\Moderate\\77e7c7a160c8.png',
#  'train\\Moderate\\77f69c7ff324.png',
#  'train\\Moderate\\7877be80901c.png',
#  'train\\Moderate\\78a577c3e0bf.png',
#  'train\\Moderate\\78d53c82a23e.png',
#  'train\\Moderate\\79059d0592c4.png',
#  'train\\Moderate\\79540be95177.png',
#  'train\\Moderate\\799cb4c816ae.png',
#  'train\\Moderate\\79be2ff796bf.png',
#  'train\\Moderate\\7a0cff4c24b2.png',
#  'train\\Moderate\\7b8c78b41c0d.png',
#  'train\\Moderate\\7bc2e0fa3f72.png',
#  'train\\Moderate\\7bda86d95c5b.png',
#  'train\\Moderate\\7c2f820a6425.png',
#  'train\\Moderate\\7c52fe73e748.png',
#  'train\\Moderate\\7d1b40fdbd86.png',
#  'train\\Moderate\\7d1da90d3ca9.png',
#  'train\\Moderate\\7d261f986bef.png',
#  'train\\Moderate\\7d37a2939f12.png',
#  'train\\Moderate\\7d8f67cadc29.png',
#  'train\\Moderate\\7dee6bf8b9c1.png',
#  'train\\Moderate\\7e6e90a93aa5.png',
#  'train\\Moderate\\7e9458de5707.png',
#  'train\\Moderate\\7ec1ffe8220b.png',
#  'train\\Moderate\\7f6ce40f306b.png',
#  'train\\Moderate\\7f84284598f5.png',
#  'train\\Moderate\\8000a6b97a84.png',
#  'train\\Moderate\\803120c5d287.png',
#  'train\\Moderate\\807135cbc438.png',
#  'train\\Moderate\\80b5a9519aec.png',
#  'train\\Moderate\\80feb1f7ca5e.png',
#  'train\\Moderate\\812d5adafaf2.png',
#  'train\\Moderate\\81b0a2651c45.png',
#  'train\\Moderate\\81bc03e2ff2b.png',
#  'train\\Moderate\\82910bba4753.png',
#  'train\\Moderate\\82deb07a6618.png',
#  'train\\Moderate\\82f2784ead76.png',
#  'train\\Moderate\\83b61051737f.png',
#  'train\\Moderate\\83d6e40c869f.png',
#  'train\\Moderate\\840527bc6628.png',
#  'train\\Moderate\\8421107255ae.png',
#  'train\\Moderate\\842d697884f6.png',
#  'train\\Moderate\\8446826853d0.png',
#  'train\\Moderate\\84e8c62165b5.png',
#  'train\\Moderate\\8543a801dce0.png',
#  'train\\Moderate\\855f0a5442b6.png',
#  'train\\Moderate\\857002ed4e49.png',
#  'train\\Moderate\\85cc6d636898.png',
#  'train\\Moderate\\85fce24084da.png',
#  'train\\Moderate\\86722fcd802c.png',
#  'train\\Moderate\\869bbd3170cc.png',
#  'train\\Moderate\\86b3a7929bec.png',
#  'train\\Moderate\\86baef833ae0.png',
#  'train\\Moderate\\86e7f98f73f1.png',
#  'train\\Moderate\\86fbac86ed3e.png',
#  'train\\Moderate\\873fe0404d6e.png',
#  'train\\Moderate\\876e1dd12d38.png',
#  'train\\Moderate\\878a3a097436.png',
#  'train\\Moderate\\879744b9dc65.png',
#  'train\\Moderate\\87b1938994b5.png',
#  'train\\Moderate\\882a71de424e.png',
#  'train\\Moderate\\8860c7b11530.png',
#  'train\\Moderate\\8871e6a26596.png',
#  'train\\Moderate\\891392c9683c.png',
#  'train\\Moderate\\89b044cbaf85.png',
#  'train\\Moderate\\89b725411cee.png',
#  'train\\Moderate\\89d2a7403a06.png',
#  'train\\Moderate\\89ee1fa16f90.png',
#  'train\\Moderate\\89fc080f7e83.png',
#  'train\\Moderate\\8a67f1efa315.png',
#  'train\\Moderate\\8a759f94613a.png',
#  'train\\Moderate\\8aab201c0691.png',
#  'train\\Moderate\\8ab8d9b3ce3f.png',
#  'train\\Moderate\\8acffaf1f4b9.png',
#  'train\\Moderate\\8b26d3cd61e8.png',
#  'train\\Moderate\\8bdb891661a8.png',
#  'train\\Moderate\\8c87bd748996.png',
#  'train\\Moderate\\8cb6b0efaaac.png',
#  'train\\Moderate\\8cb6b5b2f19c.png',
#  'train\\Moderate\\8d3d67661620.png',
#  'train\\Moderate\\8d62ba9cb22a.png',
#  'train\\Moderate\\8d7bb0649a02.png',
#  'train\\Moderate\\8dba09a4e5ed.png',
#  'train\\Moderate\\8dfa629ca74e.png',
#  'train\\Moderate\\8dfff47b06b7.png',
#  'train\\Moderate\\8e20b8fac7c3.png',
#  'train\\Moderate\\8e3b79e1f1f7.png',
#  'train\\Moderate\\8e63fc4ab532.png',
#  'train\\Moderate\\8eb3337a54e9.png',
#  'train\\Moderate\\8f1e7433a95d.png',
#  'train\\Moderate\\8ff2733f6aef.png',
#  'train\\Moderate\\9033f1493da1.png',
#  'train\\Moderate\\9041eb43456e.png',
#  'train\\Moderate\\907aaff827e5.png',
#  'train\\Moderate\\913b1890ed1e.png',
#  'train\\Moderate\\917f76f360b6.png',
#  'train\\Moderate\\91a88d3b0358.png',
#  'train\\Moderate\\91cbe1c775ef.png',
#  'train\\Moderate\\91e2c2890c9f.png',
#  'train\\Moderate\\91e8af9ceee9.png',
#  'train\\Moderate\\921433215353.png',
#  'train\\Moderate\\929cd3867815.png',
#  'train\\Moderate\\92b0d27fc0ec.png',
#  'train\\Moderate\\92d8a7c8e718.png',
#  'train\\Moderate\\92f313287a29.png',
#  'train\\Moderate\\932181b93b2f.png',
#  'train\\Moderate\\94a67ec0714f.png',
#  'train\\Moderate\\94dcb491143f.png',
#  'train\\Moderate\\9568eb7e9c08.png',
#  'train\\Moderate\\959dc602febc.png',
#  'train\\Moderate\\962cf85e4f6d.png',
#  'train\\Moderate\\96c3e3db68bc.png',
#  'train\\Moderate\\96d48b073f18.png',
#  'train\\Moderate\\975252e325e3.png',
#  'train\\Moderate\\9785805af1b8.png',
#  'train\\Moderate\\97a5ad7548b7.png',
#  'train\\Moderate\\97bf61736b86.png',
#  'train\\Moderate\\98104c8c67eb.png',
#  'train\\Moderate\\9837048b85dc.png',
#  'train\\Moderate\\98e8adcf085c.png',
#  'train\\Moderate\\98f48850ebce.png',
#  'train\\Moderate\\98f7136d2e7a.png',
#  'train\\Moderate\\9904939ab83d.png',
#  'train\\Moderate\\999115d9386b.png',
#  'train\\Moderate\\99e8bf998285.png',
#  'train\\Moderate\\9a28d4e8aef0.png',
#  'train\\Moderate\\9a3c03a5ad0f.png',
#  'train\\Moderate\\9a4f370d341b.png',
#  'train\\Moderate\\9a78c6a7b1c2.png',
#  'train\\Moderate\\9a7bd084395e.png',
#  'train\\Moderate\\9a9b21215c55.png',
#  'train\\Moderate\\9ad92f1c1542.png',
#  'train\\Moderate\\9b0eb9f41da4.png',
#  'train\\Moderate\\9b32e8ef0ca0.png',
#  'train\\Moderate\\9b418ce42c13.png',
#  'train\\Moderate\\9b7b6e4db1d5.png',
#  'train\\Moderate\\9b95d6203406.png',
#  'train\\Moderate\\9c088d2d1559.png',
#  'train\\Moderate\\9c5dd3612f0c.png',
#  'train\\Moderate\\9cedf5c7016b.png',
#  'train\\Moderate\\9d74428188bb.png',
#  'train\\Moderate\\9d98a0b585f2.png',
#  'train\\Moderate\\9d9bfefa809c.png',
#  'train\\Moderate\\9da74370835a.png',
#  'train\\Moderate\\9dab2e6ba44b.png',
#  'train\\Moderate\\9df31421cdd2.png',
#  'train\\Moderate\\9e5ec293267c.png',
#  'train\\Moderate\\9eaac43744f5.png',
#  'train\\Moderate\\9f1efb799b7b.png',
#  'train\\Moderate\\9f4132bd6ed6.png',
#  ...]

# %%
import matplotlib.pyplot as plt 
import seaborn 
  
# declaring data 
data = [44, 45, 40, 41, 39] 
keys = ['Class 1', 'Class 2', 'CLass 3', 'Class 4', 'Class 5'] 
  
# define Seaborn color palette to use 
palette_color = seaborn.color_palette('bright') 
  
# plotting data on chart 
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%') 
  
# displaying chart 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21004\2095619852.py in <cell line: 1>()
# ----> 1 plt.pie(train, labels= label)
#       2
#       3 plt.title('Pie Chart of Categories')
#       4
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
#    2745         x, explode=explode, labels=labels, colors=colors,
#    2746         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3040         # The use of float32 is "historical", but can't be changed without
#    3041         # regenerating the test baselines.
# -> 3042         x = np.asarray(x, np.float32)
#    3043         if x.ndim > 1:
#    3044             raise ValueError("x must be 1D")
#
# ValueError: could not convert string to float: 'train\\Mild\\0024cdab0c1e.png'
